# %% [markdown]
# # Preprocessing of the DTA-Rhyme Corpus
#
# Corpus: https://github.com/tnhaider/german-rhyme-corpus/tree/master/Diachron_Sample_DTA_DTR_Rhyme_Annotated
#
# This notebook takes the anotated corpus as input and outputs a list of rhyming and not rhyming pair of words.
#
# There are some problems due to inconsistencies in the

# %%
import pandas as pd
import os
from bs4 import BeautifulSoup as bs
import re
import itertools
import pickle

# %%
fpath = '/home/andreas/copyrighted_data/rhyme_corpus'

filenames = [os.path.join(fpath,fname) for fname in os.listdir(fpath) if fname.endswith('.xml')]

# %%
def get_text(raw_line):
    raw_line = re.sub('<[^>]+>', ' ', str(raw_line))
    raw_line = re.sub('\s\s+' , ' ', str(raw_line))
    raw_line = re.sub('ſ', 's', str(raw_line))
    raw_line = re.sub('uͤ', 'ü', str(raw_line))
    raw_line = re.sub('aͤ', 'ä', str(raw_line))
    raw_line = re.sub('oͤ', 'ö', str(raw_line)).lower()
    raw_line = re.sub(r'[^a-zäöü ]', '', str(raw_line))
    
    return raw_line

line_lst = []
rhyme_lst = []
problem_lst = []

corr_lst = []
f_lst = []

error_cnt = 0
solved_cnt = 0
no_rhyme_cnt = 0

for file in filenames:
    with open(file, "r",encoding="utf-8") as file:
        # Read each line in the file, readlines() returns a list of lines
        content = file.readlines()
        # Combine the lines in the list into a string
        content = "".join(content)
        bs_content = bs(content, "lxml")

    result = bs_content.find_all("lg")
    for item in result:
        solved = 0
        bs_item = bs(str(item),'lxml')
        
        subitems = bs_item.find_all('lg')
        if len(subitems) <= 1:
            try:
                rhyme = re.search(r'rhyme=\"(.*?)\"', str(item)).group(1)
            except: 
                rhyme = 'z'
            lines = bs_item.find_all('l')
            
            lines_clean = []
            for line in lines:
                valid = True
                text = get_text(line)
                if re.search(r'<l><hi rendition="c',str(line)):   # rendition c indicates the use of blocks
                                                                      # but contains content at author Holz Arno
                    line_body = re.sub('<[^>]+>', '', str(line))
                    if len(line_body < 7) or line[:-1].isdecimal():  #[:-1] because of dot
                        valid = False
                    if re.search(r'<hi rendition="#et',str(line)) and line_body < 10:
                        valid = False
                
                        
                if re.search(r'<l><hi rendition="#et',str(line)):   #rendition et at beginning of line indicates
                                                                        #that it might be appended to the previous line
                    words = re.sub('<[^>]+>', '', str(line)).split()
                    
                    
                        
                    if len(words) < 3 and len(lines_clean) > 0:
                        lines_clean[-1] += ' ' + text
                        valid = False
                        solved = 1
                        
                if valid:
                    lines_clean.append(text)

            lines = [line for line in lines_clean if line] 
            
            
            if len(lines) != len(rhyme):
                print('######## error #########')
                print('rhyme:')
                print(rhyme)
                print('lines:')
                print(lines)
                print('file:')
                print(file)
                print('item:')
                print(str(item))
                print('\n')
                solved = 0
                error_cnt +=1
                
                '''lines_corr = []
                cnt = 0
                while cnt < len(lines): 
                    if cnt < len(lines)-1:
                        if len(lines[cnt+1].split()) < 3:
                            lines_corr.append(lines[cnt] + ' ' + lines[cnt + 1])
                            cnt += 2
                        else:
                            lines_corr.append(lines[cnt])
                            cnt +=1
                    else: 
                        lines_corr.append(lines[cnt])
                        cnt +=1                   
                
                
                if len(lines_corr) != len(rhyme): 
                    problem_lst.append(2)
                    cnt_p1 +=1
                    line_lst.append(lines)
                else: 
                    problem_lst.append(1)
                    line_lst.append(lines_corr)'''
            elif rhyme == 'z':
                no_rhyme_cnt += 1
            else:
                problem_lst.append(0)
                line_lst.append(lines)
                rhyme_lst.append(rhyme)
                f_lst.append(file)
                
            solved_cnt += solved
        else:
            pass

# %%
no_rhyme_cnt
# Out:
# 168

# %% [markdown]
# # Just for illustration purposes
#
# The cell belows shows the inconsistent use for "<l><\l>" in the corpus.
#
# Sometimes "<\l>" comes inside a vers and sometimes indeed it marks the complete verse even if it spreads on two lines

# %%
for file in filenames:
    with open(file, "r",encoding="utf-8") as file:
        # Read each line in the file, readlines() returns a list of lines
        content = file.readlines()
        # Combine the lines in the list into a string
        content = "".join(content)
        bs_content = bs(content, "lxml")

    result = bs_content.find_all("lg")
    for item in result:
        bs_item = bs(str(item),'lxml')
        
        subitems = bs_item.find_all('lg')
        if len(subitems) <= 1:
            try:
                rhyme = re.search(r'rhyme=\"(.*?)\"', str(item)).group(1)
            except: 
                rhyme = 'z'
            lines = bs_item.find_all('l')
            
            for i in range(len(lines)):
                if re.search(r'<l><hi rendition="#et">',str(lines[i])):
                    print('#et at beginning of verse')
                    print('verse:')
                    print(str(lines[i]))
                    print('file:')
                    print(str(file))
                    
            for i in range(len(lines)):
                if (not re.search(r'<l><hi rendition="#et">',str(lines[i]))) and re.search(r'rendition="#et">',str(lines[i])):
                    print('\n')
                    print('#et inside verse')
                    print('verse:')
                    print(str(lines[i]))
                    print('file:')
                    print(str(file))
# Out:
# #et inside verse
# verse:
# <l>Daſs dich, mit goldenen Städten und<lb></lb>
# <hi rendition="#et">Schlachten,</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Zum hohen Kapitol dein ſtolzer Wagen<lb></lb>
# <hi rendition="#et">trug. —</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l><hi rendition="#in">O</hi> du, dem glühend Eiſen, donnernd<lb></lb>
# <hi rendition="#et">Feuer</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Die frommen Dichter zu zerſchmettern,<lb></lb>
# <hi rendition="#et">Ungeheuer,</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Wer zur Verheerung blühender Ge-<lb></lb>
# <hi rendition="#et">ſchlechter</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Hat ohne Reue ſeine Mutter, ſeine<lb></lb>
# <hi rendition="#et">Töchter</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Ganz nahe war ich ſchon dem Styx,<lb></lb>
# <hi rendition="#et">ganz nahe</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Ich hörte ſchon das Rad Ixions raſſeln,<lb></lb>
# <hi rendition="#et">ſahe</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Verdammt zum Spott bey bodenloſen<lb></lb>
# <hi rendition="#et">Fäſſern;</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Elyſiens; den groſsen Ahnherrn eines<lb></lb>
# <hi rendition="#et">gröſſern</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Voll tapfrer Brennen ſah ich: ihre<lb></lb>
# <hi rendition="#et">Lieder,</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Iſt er, der wider ſechs Monarchen ſicht,<lb></lb>
# <hi rendition="#et">und wider</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Schon ſäng’ ich ſeine jüngſte That: wie<lb></lb>
# <hi rendition="#et">brauſend</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>Er aber ſeinen Weg hindurch auf zehen-<lb></lb>
# <hi rendition="#et">tauſend</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>
</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# #et at beginning of verse
# verse:
# <l><hi rendition="#et">Daß ich euch daſſelbe thu/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# #et at beginning of verse
# verse:
# <l><hi rendition="#et">Der ſchoͤnen Augen-Glantz</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# #et at beginning of verse
# verse:
# <l><hi rendition="#et">Verdienet Kron’ und Krantz/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# #et at beginning of verse
# verse:
# <l><hi rendition="#et">Deiner holden Schoͤnheit-Zier</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# #et at beginning of verse
# verse:
# <l><hi rendition="#et">Stelt kein ſchlechter Pinſul fuͤr.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# #et at beginning of verse
# verse:
# <l><hi rendition="#et">Stelle mir daſſelbe zu/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# #et at beginning of verse
# verse:
# <l><hi rendition="#et">So vermehrſt du meine Ruh/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Triebe des Hirten Geſang nur eine Muͤhle des Thals!</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Wenn, aus der Pfeife gejagt, er nicht Getraide noch</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Treibt es nicht drohend Gewoͤlk' uͤber dem Acker mir weg.</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Spendet nicht Waſſer ſein Mund, traͤgt es nicht ſtuͤtzend</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Nicht ein Koͤrnlein, bei Gott! weckt ihr unpraktiſcher</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Macht welk dein Herz der Menſchen Qual;</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">In dieſes unterird'ſche Thal.</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Dich an die Bruſt und loͤſt den Schmerz.</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Erwaͤrmt dich hier ihr Mutterherz.</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Hier aus kryſtallnen Tiefen laut:</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">„Der liebend unſrer Kraft vertraut.“</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Der Mutter ſich vertrauend legt,</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Von Lieb' und Hoffnung ſtill bewegt.</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Frag' nicht, wie dieſe Kraft man heißt;</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Und ſprichſt: das that des Wildbads Geiſt!</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>

# %% [markdown]
# # Rendition test
#
# Find and display uses of different renditions

# %%
rendition ='rendition="#c'

for file in filenames:
    with open(file, "r",encoding="utf-8") as file:
        # Read each line in the file, readlines() returns a list of lines
        content = file.readlines()
        # Combine the lines in the list into a string
        content = "".join(content)
        bs_content = bs(content, "lxml")

    result = bs_content.find_all("lg")
    for item in result:
        bs_item = bs(str(item),'lxml')
        
        subitems = bs_item.find_all('lg')
        if len(subitems) <= 1:
            try:
                rhyme = re.search(r'rhyme=\"(.*?)\"', str(item)).group(1)
            except: 
                rhyme = 'z'
            lines = bs_item.find_all('l')
            
            for i in range(len(lines)):
                if re.search(rendition,str(lines[i])):
                    print('\n')
                    print('verse:')
                    print(str(lines[i]))
                    print('file:')
                    print(str(file))
                    line = re.sub('<[^>]+>', '', str(lines[i]))
                    print(line)
                    if line[:-1].isdecimal():
                        print('numeric')
# Out:
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">12.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 12.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">den:</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Abschatz_HansAssmannvon_1704_gold_p50_s95_TEI-P5.xml' mode='r' encoding='utf-8'>
# den:
#
#
# verse:
# <l>Mich kan kein fremder Zeug bey eignem Mangel ſchmuͤ-<lb></lb>
# <hi rendition="#c">cken/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Abschatz_HansAssmannvon_1704_gold_p50_s95_TEI-P5.xml' mode='r' encoding='utf-8'>
# Mich kan kein fremder Zeug bey eignem Mangel ſchmuͤ-
# cken/
#
#
# verse:
# <l><hi rendition="#c">ren an/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Abschatz_HansAssmannvon_1704_gold_p50_s95_TEI-P5.xml' mode='r' encoding='utf-8'>
# ren an/
#
#
# verse:
# <l><hi rendition="#c">winnen.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Abschatz_HansAssmannvon_1704_gold_p50_s95_TEI-P5.xml' mode='r' encoding='utf-8'>
# winnen.
#
#
# verse:
# <l>Wer kan mit Macht entgehn dem groſſen Allmachts-Grim-<lb></lb>
# <hi rendition="#c">me?</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Abschatz_HansAssmannvon_1704_gold_p50_s95_TEI-P5.xml' mode='r' encoding='utf-8'>
# Wer kan mit Macht entgehn dem groſſen Allmachts-Grim-
# me?
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">12.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 12.
# numeric
#
#
# verse:
# <l><hi rendition="#c">13.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 13.
# numeric
#
#
# verse:
# <l><hi rendition="#c">14.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 14.
# numeric
#
#
# verse:
# <l><hi rendition="#c">15.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 15.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi>
# <hi rendition="#et">(ſey/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# (ſey/
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi>
# <hi rendition="#et">(ben/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# (ben/
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi> (faͤhret/</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4. (faͤhret/
#
#
# verse:
# <l><hi rendition="#c">5.</hi> (len/</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5. (len/
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">12.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 12.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi>
# <hi rendition="#et">(tzen/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# (tzen/
#
#
# verse:
# <l><hi rendition="#c">10.</hi>
# <hi rendition="#et">(men/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# (men/
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">12.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 12.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi>
# <hi rendition="#et">(Ruh/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# (Ruh/
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# ...
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi>
# <hi rendition="#et">(Erde/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# (Erde/
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi>
# <hi rendition="#et">(cken/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# (cken/
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c"><hi rendition="#fr">Ach! vnd weh!</hi></hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gryphius_Andreas_1650_gold_p49_s189_TEI-P5.xml' mode='r' encoding='utf-8'>
# Ach! vnd weh!
#
#
# verse:
# <l><hi rendition="#c"><hi rendition="#fr">Tieff’ vnd Hoͤh’!</hi></hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gryphius_Andreas_1650_gold_p49_s189_TEI-P5.xml' mode='r' encoding='utf-8'>
# Tieff’ vnd Hoͤh’!
#
#
# verse:
# <l><hi rendition="#c"><hi rendition="#fr">Je vnd Eh!</hi></hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gryphius_Andreas_1650_gold_p49_s189_TEI-P5.xml' mode='r' encoding='utf-8'>
# Je vnd Eh!
#
#
# verse:
# <l><hi rendition="#c"><hi rendition="#aq">Roſ.</hi></hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Weise_Christian_1701_gold_p49_s308_TEI-P5.xml' mode='r' encoding='utf-8'>
# Roſ.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-95e7c898bbf3> in <module>
#      11     result = bs_content.find_all("lg")
#      12     for item in result:
# ---> 13         bs_item = bs(str(item),'lxml')
#      14
#      15         subitems = bs_item.find_all('lg')
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     346             self.reset()
#     347             try:
# --> 348                 self._feed()
#     349                 success = True
#     350                 break
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/__init__.py in _feed(self)
#     432         self.builder.reset()
#     433
# --> 434         self.builder.feed(self.markup)
#     435         # Close out any unfinished strings and close all the open tags.
#     436         self.endData()
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/builder/_lxml.py in feed(self, markup)
#     322         try:
#     323             self.parser = self.parser_for(encoding)
# --> 324             self.parser.feed(markup)
#     325             self.parser.close()
#     326         except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed()
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxTargetStartNoNs()
#
# src/lxml/saxparser.pxi in lxml.etree._callTargetSaxStart()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/builder/_lxml.py in start(self, name, attrs, nsmap)
#     255         namespace, name = self._getNsTag(name)
#     256         nsprefix = self._prefix_for_namespace(namespace)
# --> 257         self.soup.handle_starttag(name, namespace, nsprefix, attrs)
#     258
#     259     def _prefix_for_namespace(self, namespace):
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos)
#     694         """
#     695         # print("Start tag %s: %s" % (name, attrs))
# --> 696         self.endData()
#     697
#     698         if (self.parse_only and len(self.tagStack) <= 1
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/__init__.py in endData(self, containerClass)
#     543         occurs.
#     544         """
# --> 545         containerClass = self.string_container(containerClass)
#     546
#     547         if self.current_data:
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/__init__.py in string_container(self, base_class)
#     486         # On top of that, we may be inside a tag that needs a special
#     487         # container class.
# --> 488         if self.string_container_stack:
#     489             container = self.builder.string_containers.get(
#     490                 self.string_container_stack[-1].name, container
#
# KeyboardInterrupt:

# %%
rhyme_df = pd.DataFrame(list(zip(line_lst, rhyme_lst,problem_lst,f_lst)),
               columns =['text', 'rhyme','problem','file'])

# %%
rhyme_df.to_csv('rhyme_df.csv')

# %%
picklefile = open('rhyme_df.pkl', 'wb')
pickle.dump(rhyme_df[['text','rhyme']], picklefile)

# %%
rhyme_df
# Out:
#                                                    text rhyme  problem  \
# 0     [o du dem glühend eisen donnerndfeuer, aus off...  abab        0
# 1     [wer zur verheerung blühender geschlechter, di...  abab        0
# 2     [ganz nahe war ich schon dem styxganz nahe, de...  abab        0
# 3     [verdammt zum spott bey bodenlosenfässern, und...  abab        0
# 4     [voll tapfrer brennen sah ich ihrelieder, ihr ...  abab        0
# ...                                                 ...   ...      ...
# 8359  [quält schmerz und krankheit deine glieder, ma...  abab        0
# 8360  [hier legt natur mit linden armen, dich an die...  abab        0
# 8361  [der wasser gute geister singen, hier aus krys...  abab        0
# 8362  [ja kranker wie ein kind ans herze, der mutter...  abab        0
# 8363  [wie lenzeshauch wirds dich durchbeben, frag n...  abab        0
#
#                                                    file
# 0     <_io.TextIOWrapper name='rhyme_corpus/Ramler_K...
# 1     <_io.TextIOWrapper name='rhyme_corpus/Ramler_K...
# 2     <_io.TextIOWrapper name='rhyme_corpus/Ramler_K...
# 3     <_io.TextIOWrapper name='rhyme_corpus/Ramler_K...
# 4     <_io.TextIOWrapper name='rhyme_corpus/Ramler_K...
# ...                                                 ...
# 8359  <_io.TextIOWrapper name='rhyme_corpus/Kerner_J...
# 8360  <_io.TextIOWrapper name='rhyme_corpus/Kerner_J...
# 8361  <_io.TextIOWrapper name='rhyme_corpus/Kerner_J...
# 8362  <_io.TextIOWrapper name='rhyme_corpus/Kerner_J...
# 8363  <_io.TextIOWrapper name='rhyme_corpus/Kerner_J...
#
# [8364 rows x 4 columns]

# %%
from preprocess_rhymes import rhyming_words

# %%
rhyming_words(rhyme_df)
# Out:
#                word1                   word2  rhyme
# 0      donnerndfeuer  zerschmetternungeheuer      1
# 1             flammt                  stammt      1
# 2       geschlechter            seinetöchter      1
# 3           gebracht              umgebracht      1
# 4               nahe             rasselnsahe      1
# ...              ...                     ...    ...
# 43440        bringen                vertraut      0
# 43441          herze                    legt      0
# 43442       schmerze                  bewegt      0
# 43443     durchbeben                    heit      0
# 43444          leben                   geist      0
#
# [43445 rows x 3 columns]

# %%
rhyme_pairs = []
no_rhyme_pairs = []

rhyme_df_clean = rhyme_df.drop(rhyme_df[rhyme_df['problem']>0].index)

for index, row in rhyme_df_clean.iterrows():
    
    scheme = row['rhyme']
    sent = row['text']
    file = row['file']
    new_pairs = []
    letters = set(scheme)
    for letter in letters:
        indices = [idx for idx, char in enumerate(scheme) if char == letter]
        
        if len(indices) >= 2: 
            new_pair = [sent[i].split()[-1] for i in indices]
            new_pairs.append(new_pair)
                
            if len(indices) > 2:
                rhyme_pairs += [list(item) for item in list(itertools.combinations(new_pair,2))]
            elif len(indices) == 2:
                rhyme_pairs.append(new_pair)

        else:
            #print(sent)
            #print(scheme)
            #print(indices)
            pass
        
    for idx in range(len(new_pairs)-1):                                          # ugly, but does the job fast
        try:
            no_rhyme_pairs.append([new_pairs[idx][0],new_pairs[idx+1][0]])
            no_rhyme_pairs.append([new_pairs[idx][1],new_pairs[idx+1][1]])
        except:
            pass
# Out:
# ['oanfang sonder ende', 'du grosses a und o', 'wir küssen deine hände', 'und sind von hertzen froh', 'weil du uns noch ein jahr', 'mit segen läst beschlüssen', 'da wir bekennen müssen', 'dein thun sey wunderbar']
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['der letzte wochentag                            ist hin', 'davor ich dir verbunden bin', 'du bist mein gott das a und o', 'und deine weiheit schafft es so']
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['mein freund ein schüler von apollen', 'ein meister in der homelie herr professor e  b                                 d', 'glaubt da die tauben küssen wollen', 'aus zärtlichkeit und harmonie']
# <_io.TextIOWrapper name='rhyme_corpus/Karsch_AnnaLuise_1792_gold_p7_s50_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['so lange eine menschheit ist', 'so lange jesus bleibt der christ', 'so bleibet di das a und o', 'vom gantzen evangelio', 'und da dasselbige die weiheit ist', 'das wit ihr alle die ihr wahrheit wit']
# <_io.TextIOWrapper name='rhyme_corpus/Zinzendorf_NicolausLudwigvon_1735_gold_p23_s289_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['doch hört nur mein monsieur', 'verstand die fintenvolle', 'vorherstudirte rolle', 'wie ich mein a b c', 'war er aktör ich wette', 'da man geklatschet hätte']
# <_io.TextIOWrapper name='rhyme_corpus/BБrger_GottfriedAugust_1778_gold_p34_s360_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['drum rath ich immer lieber christ', 'las dich mit keinem ein', 'wann der kontrakt geschlossen ist', 'bricht man dir hals und bein', 'troz allen klauseln glaube du', 'macht jeder dir ein x für u ']
# <_io.TextIOWrapper name='rhyme_corpus/BБrger_GottfriedAugust_1778_gold_p34_s360_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['im letste wirthshus hangt e sack', 'und wenn de furt gohsch henk en a', 'du alte lump wie stoht der nit', 'der bettelsack so zierlig a']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['druf redt der chnab mi büebli a', 'was iisch i halts mit ', 'he nüt seit s büebli luegt en a', 'und lüpft si chäppli nit', 'druf seit der chnab he iisch nüt', 'du grobe burst se battet s nüt']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['wer spöchtet mer mi hexli us', 'wer zeigtmer siner mutter hus', 'j lauf no was i laufe cha', 'wer wei se triffis doch no a']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['weisch jobbeli was der morgestern', 'am himmel sucht me seits nit gern', 'er wandlet imme sternli no', 'er cha schier gar nit vonnem lo', 'doch meint si mutter s müe nit sy', 'und thut en wie ne hüenli i']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['dört chunnt sie scho i has io gseit', 'in ihrer stille herlichkeit', 'sie zündet ihri strahlen a', 'der chilchthurn wärmt si au scho dra', 'und wo sie fallen in berg und thal', 'se rüehrt si s leben überal']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['was wandlet dört im morgestral', 'mit tuch und chorb durs mattethal', 's sin dmeidli iung und flink und froh', 'sie bringe weger dsnppesuppe scho', 'und s anne meili vornen a', 'es lacht mi scho vo witem a']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# 

# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['doch fangt e büebli z raucheurauchen a', 'und meint es chönns as wie ne ma', 'se macht der schmelzer churze bricht', 'und zieht em s pfifli usem gsicht']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['jez schenket i und stoet a', 'der hammermeister isch au ne ma', 'wär hammerschmid und zeiner nit', 'do läg e sach was thät me mit']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['und glitte was me lide cha', 'drum schenket i und stoet a', 'uf völker fried und einigkeit', 'vo nun a bis in ewigkeit']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>

# %%
rhyme_stat = [1]*len(rhyme_pairs) + [0]*len(no_rhyme_pairs)
pairs = rhyme_pairs + no_rhyme_pairs

for pair in pairs:
    
    if len(pair) < 1:
        print(pair)
word_1 = [pair[0] for pair in pairs]
word_2 = [pair[1] for pair in pairs]

rhyme_word_df = pd.DataFrame(list(zip(word_1, word_2,rhyme_stat)),
               columns =['word1', 'word2','rhyme'])

# %%
rhyme_word_df
# Out:
#                word1                   word2  rhyme
# 0      donnerndfeuer  zerschmetternungeheuer      1
# 1             flammt                  stammt      1
# 2       geschlechter            seinetöchter      1
# 3           gebracht              umgebracht      1
# 4               nahe             rasselnsahe      1
# ...              ...                     ...    ...
# 43440        bringen                vertraut      0
# 43441          herze                    legt      0
# 43442       schmerze                  bewegt      0
# 43443     durchbeben                    heit      0
# 43444          leben                   geist      0
#
# [43445 rows x 3 columns]

# %%
stat_df = rhyme_word_df.copy()

stat_df['len word1'] = stat_df['word1'].apply(lambda x: len(x))
stat_df['len word2'] = stat_df['word2'].apply(lambda x: len(x))
pd.set_option('display.max_rows', 200)
stat_df.sort_values(by=['len word2']).head(100)
# Out:
#                      word1 word2  rhyme  len word1  len word2
# 43041                 keim     a      0          4          1
# 20259                    a     a      1          1          1
# 20081                    a     a      1          1          1
# 28217                 jahr     o      0          4          1
# 42818                  hus     a      0          3          1
# 20281                   la     a      1          2          1
# 20156                   ha     a      1          2          1
# 42842                 gern     i      0          4          1
# 41848                  ist     u      0          3          1
# 19279                   du     u      1          2          1
# 42995                 echt     a      0          4          1
# 20309                   ma     a      1          2          1
# 20145                    a     a      1          1          1
# 20258                  cha     a      1          3          1
# 42965                   io     a      0          2          1
# 42865           morgestral     a      0         10          1
# 20353                  cha     a      1          3          1
# 42982                 gott     a      0          4          1
# 20325                   ma     a      1          2          1
# 20108                  cha     a      1          3          1
# 20327              biderma     a      1          7          1
# 36297                  ist     o      0          3          1
# 42936                stoht     i      0          5          1
# 20127                   sy     i      1          2          1
# 42859                 thal     a      0          4          1
# 33207              apollen     d      0          7          1
# 19123             monsieur     c      1          8          1
# 42866            mattethal     a      0          9          1
# 20257                  cha     a      1          3          1
# 20295                   ma     a      1          2          1
# 20069                    a     a      1          1          1
# 20198                   ma     a      1          2          1
# 20232                   ma     a      1          2          1
# 20197            morgeschi     i      1          9          1
# 28697                  hin     o      0          3          1
# 20204                   ma     a      1          2          1
# 24718              gesogen    an      0          7          2
# 1012              gleichlo    ro      1          8          2
# 42675       jungferschafft    sü      0         14          2
# 36330                  her    an      0          3          2
# 27336                würde    ba      0          5          2
# 1922                  nahn    an      1          4          2
# 11102                  ruh    zu      1          3          2
# 892                    nah    da      1          3          2
# 11108                 dann    an      1          4          2
# 36331             bestellt    du      0          8          2
# 36332                 welt    du      0          4          2
# 20998  feuerspeyndenrachen    da      0         19          2
# 1986                    an    an      1          2          2
# 11115                 kann    an      1          4          2
# 29389             springet    ju      0          8          2
# 6312                  grab    ab      1          4          2
# 9288                  etat    da      1          4          2
# 29386                 alda    zu      0          4          2
# 11122                daher    er      1          5          2
# 32611                  mir    an      0          3          2
# 11124                   zu    du      1          2          2
# 17427                 flei    ei      1          4          2
# 36356                windt    da      0          5          2
# 3189                    an    an      1          2          2
# 4442                hurrah    da      1          6          2
# 32761               gehege    an      0          6          2
# 11128                 mann    an      1          4          2
# 34263                drauf    ab      0          5          2
# 22877                tagen    an      0          5          2
# 20941      frankensprechet    an      0         15          2
# 22878        ausgeschlagen    an      0         13          2
# 19114                  ruh    zu      1          3          2
# 18976                  her    er      1          3          2
# 14869           hallelujah    da      1         10          2
# 14868                  sah    da      1          3          2
# 14692                 gewi    di      1          4          2
# 32512                ehren    an      0          5          2
# 27422               fische    an      0          6          2
# 23088        hahnreyschaft    an      0         13          2
# 6859                   kan    an      1          3          2
# 28621              anficht    ge      0          7          2
# 4455                hurrah    da      1          6          2
# 28698                  bin    so      0          3          2
# 4454                hurrah    da      1          6          2
# 42981                 brod    ma      0          4          2
# 23081              gesteht    so      0          7          2
# 28625                steht    an      0          5          2
# 4451                hurrah    da      1          6          2
# 4450                hurrah    da      1          6          2
# 4447                hurrah    da      1          6          2
# 4446                hurrah    da      1          6          2
# 11087                  ruh    zu      1          3          2
# 42266              geküsst    an      0          7          2
# 4443                hurrah    da      1          6          2
# 26515                 ehre    an      0          4          2
# 4312                   ruh    zu      1          3          2
# 6282                    du    zu      1          2          2
# 4331                    zu    du      1          2          2
# 38027               garten    ku      0          6          2
# 38026             hortulan    zu      0          8          2
# 38025                   an    du      0          2          2
# 38023              beweget    an      0          7          2
# 22985                 wort    du      0          4          2
# 13721                 dann    an      1          4          2

# %%
shuffled_df = rhyme_word_df.sample(frac=1).reset_index(drop=True)

# %%
ratio = 0.8

df_train = shuffled_df[:int(len(shuffled_df)*ratio)]
df_val = shuffled_df[int(len(shuffled_df)*ratio):]

df_train.to_csv('data/train.csv',index=False)
df_val.to_csv('data/val.csv',index=False)

shuffled_df.to_csv('data/rhymes_clean.csv', index=False)

# %%
label_dict = {1:'y',0:'n'}

train_data_df = shuffled_df.copy()

train_data_df['rhyme'] = train_data_df['rhyme'].apply(lambda x: label_dict[x])

train_data_df.to_csv('data/rhymes_clean.tsv', index=False, sep='\t',header = None)


train_data_df
# Out:
#             word1         word2 rhyme
# 0         geblühm         dräut     n
# 1         gleicht        anbeut     n
# 2          saamen         namen     y
# 3          bliebe         liebe     y
# 4         wiedere       niedere     y
# ...           ...           ...   ...
# 42633  geschlacht       gemacht     y
# 42634      rächet     schwächet     y
# 42635      bereit      ewigkeit     y
# 42636       leise          brot     n
# 42637       empor  felsengrotte     n
#
# [42638 rows x 3 columns]

# %%
# Out:
# 'aber oh  du'
