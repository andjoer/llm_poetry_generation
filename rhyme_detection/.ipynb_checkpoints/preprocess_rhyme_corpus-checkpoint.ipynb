# %%
import pandas as pd
import os
from bs4 import BeautifulSoup as bs
import re
import itertools

# %%
fpath = 'rhyme_corpus'

filenames = [os.path.join(fpath,fname) for fname in os.listdir(fpath) if fname.endswith('.xml')]

# %%
def get_text(raw_line):
    raw_line = re.sub('<[^>]+>', '', str(raw_line))
    raw_line = re.sub('ſ', 's', str(raw_line))
    raw_line = re.sub('uͤ', 'ü', str(raw_line))
    raw_line = re.sub('aͤ', 'ä', str(raw_line))
    raw_line = re.sub('oͤ', 'ö', str(raw_line)).lower()
    raw_line = re.sub(r'[^a-zäöü ]', '', str(raw_line))
    
    return raw_line

line_lst = []
rhyme_lst = []
problem_lst = []

corr_lst = []
f_lst = []

error_cnt = 0
solved_cnt = 0
no_rhyme_cnt = 0

for file in filenames:
    with open(file, "r",encoding="utf-8") as file:
        # Read each line in the file, readlines() returns a list of lines
        content = file.readlines()
        # Combine the lines in the list into a string
        content = "".join(content)
        bs_content = bs(content, "lxml")

    result = bs_content.find_all("lg")
    for item in result:
        solved = 0
        bs_item = bs(str(item),'lxml')
        
        subitems = bs_item.find_all('lg')
        if len(subitems) <= 1:
            try:
                rhyme = re.search(r'rhyme=\"(.*?)\"', str(item)).group(1)
            except: 
                rhyme = 'z'
            lines = bs_item.find_all('l')
            
            lines_clean = []
            for line in lines:
                valid = True
                text = get_text(line)
                if re.search(r'<l><hi rendition="c',str(line)):   # rendition c indicates the use of blocks
                                                                      # but contains content at author Holz Arno
                    line_body = re.sub('<[^>]+>', '', str(line))
                    if len(line_body < 7) or line[:-1].isdecimal():  #[:-1] because of dot
                        valid = False
                    if re.search(r'<hi rendition="#et',str(line)) and line_body < 10:
                        valid = False
                
                if re.search(r'<l><hi rendition="#et',str(line)):   #rendition et at beginning of line indicates
                                                                        #that it might be appended to the previous line
                    words = re.sub('<[^>]+>', '', str(line)).split()
                    
                    if len(words) < 3 and len(lines_clean) > 0:
                        lines_clean[-1] += text
                        valid = False
                        solved = 1
                        
                if valid:
                    lines_clean.append(text)

            lines = [line for line in lines_clean if line] 
            
            
            if len(lines) != len(rhyme):
                print('######## error #########')
                print('rhyme:')
                print(rhyme)
                print('lines:')
                print(lines)
                print('file:')
                print(file)
                print('item:')
                print(str(item))
                print('\n')
                solved = 0
                error_cnt +=1
                
                '''lines_corr = []
                cnt = 0
                while cnt < len(lines): 
                    if cnt < len(lines)-1:
                        if len(lines[cnt+1].split()) < 3:
                            lines_corr.append(lines[cnt] + ' ' + lines[cnt + 1])
                            cnt += 2
                        else:
                            lines_corr.append(lines[cnt])
                            cnt +=1
                    else: 
                        lines_corr.append(lines[cnt])
                        cnt +=1                   
                
                
                if len(lines_corr) != len(rhyme): 
                    problem_lst.append(2)
                    cnt_p1 +=1
                    line_lst.append(lines)
                else: 
                    problem_lst.append(1)
                    line_lst.append(lines_corr)'''
            elif rhyme == 'z':
                no_rhyme_cnt += 1
            else:
                problem_lst.append(0)
                line_lst.append(lines)
                rhyme_lst.append(rhyme)
                f_lst.append(file)
                
            solved_cnt += solved
        else:
            pass
# Out:
# ######## error #########
# rhyme:
# None
# lines:
# ['schäme dich kamill', 'dass du mit vier sonnenpferden', 'in dein errettetes rom zogst', 'und du romulischer feinde', 'glücklicher sieger o julius', 'dass dich mit goldenen städten undschlachten', 'und mit adlern und spolien', 'deiner brüder umgeben', 'zum hohen kapitol dein stolzer wagentrug ', 'friederich ein prinz der brennen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="None" type="stanza">
# <l><hi rendition="#in">S</hi>chäme dich, Kamill,</l>
# <lb></lb>
# <l>Daſs du mit vier Sonnenpferden</l>
# <lb></lb>
# <l>In dein errettetes Rom zogſt!</l>
# <lb></lb>
# <l>Und du, Romuliſcher Feinde</l>
# <lb></lb>
# <l>Glücklicher Sieger, o Julius,</l>
# <lb></lb>
# <l>Daſs dich, mit goldenen Städten und<lb></lb>
# <hi rendition="#et">Schlachten,</hi></l>
# <lb></lb>
# <pb facs="#f0083" n="77"></pb>
# <l>Und mit Adlern und Spolien</l>
# <lb></lb>
# <l>Deiner Brüder umgeben,</l>
# <lb></lb>
# <l>Zum hohen Kapitol dein ſtolzer Wagen<lb></lb>
# <hi rendition="#et">trug. —</hi></l>
# <lb></lb>
# <l><hi rendition="#g">Friederich,</hi> ein Prinz der Brennen,</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# None
# lines:
# []
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="None" type="stanza">
# <l></l>
# <lb></lb>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbcca
# lines:
# ['wie gerne wär ich einmahl mein', 'wie gerne möcht ich dich erblikken', 'wie gerne mich bey dir erqwikken', 'dein brot gemengt au schwartzer kleyen sollt über manna mir gedeyen', 'dein wassertrunk als nektar sein']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="6" rhyme="abbcca" type="stanza">
#             6.
#             <lb></lb>
# <l>Wie gerne waͤr’ ich einmahl mein!</l>
# <lb></lb>
# <l>wie gerne moͤcht’ ich dich erblikken<hi rendition="#i">!</hi></l>
# <lb></lb>
# <l>wie gerne mich bey dir erqwikken!</l>
# <lb></lb>
# <l>dein Brot gemengt auß ſchwartzer Kleyen<lb></lb> ſollt’ uͤber Manna mir gedeyen/</l>
# <lb></lb>
# <l>dein Waſſer-trunk als Nektar ſein:</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbcca
# lines:
# ['jch bin kein stein ich lasse mich', 'auff ihre klag alsdenn erweichen so pflegt die zeit vorbey zu streichen', 'ich habe freund dich nicht gesprochen', 'da meinstu denn es sey gebrochen', 'was uns verbindet mich und dich']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="9" rhyme="abbcca" type="stanza">
#             9.
#             <lb></lb>
# <l>Jch bin kein Stein/ ich laſſe mich</l>
# <lb></lb>
# <l>auff ihre Klag’ alsdenn erweichen/<lb></lb> ſo pflegt die Zeit vorbey zu ſtreichen.</l>
# <lb></lb>
# <l>ich habe/ Freund/ dich nicht geſprochen</l>
# <lb></lb>
# <l>da meinſtu denn/ es ſey gebrochen/</l>
# <lb></lb>
# <l>was uns verbindet/ mich und dich.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbcca
# lines:
# ['jch wei nicht was für haltnü doch', 'der schmeichlend amor in sich heget', 'der freyheit pa wird nur verlegeticherstes zehen', 'ich kan au seinen zauberketten', 'mich durch kein einig mittel retten so sehr beschweret mich sein joch']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="10" rhyme="abbcca" type="stanza">
#             10.
#             <lb></lb>
# <l>Jch weiß nicht/ was fuͤr Haltnuͤß doch</l>
# <lb></lb>
# <l>der ſchmeichlend’ Amor in ſich heget.</l>
# <lb></lb>
# <l>Der Freyheit Paß wird nur verleget<lb></lb>
# <fw place="bottom" type="catch">ich</fw><lb></lb>
# <pb facs="#f0059" n="27"></pb>
# <fw place="top" type="header"><hi rendition="#b">Erſtes Zehen.</hi></fw></l>
# <lb></lb>
# <l>ich kan auß ſeinen Zauber-Ketten</l>
# <lb></lb>
# <l>mich durch kein einig Mittel retten/<lb></lb> ſo ſehr beſchweret mich ſein Joch.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbacc
# lines:
# ['dennoch sind wir nicht getrennet', 'filidor ist allzeit dein solt er auch in zimmern sein', 'wo man keine sonne kennet', 'deine fakkel macht ihn lichte', 'bey dem schwarzen nachtgesichte']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="3" rhyme="abbacc" type="stanza">
#             3.
#             <lb></lb>
# <l>Dennoch ſind wir nicht getrennet.</l>
# <lb></lb>
# <l>Filidor iſt allzeit dein/<lb></lb> ſolt’ er auch in Zimmern ſein</l>
# <lb></lb>
# <l>wo man keine Sonne kennet/</l>
# <lb></lb>
# <l>deine Fakkel macht ihn lichte</l>
# <lb></lb>
# <l>bey dem ſchwarzen Nacht-geſichte.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbacc
# lines:
# ['bey dem günstigem südwesten schweer ichs telesille dir', 'dein verbleib ich für und fürm iiijgibgeharnschter venus', 'gib mein schiff den felsenästen', 'zesyrsbruder wo ich liege', 'und mein liebstes kind betriege']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="4" rhyme="abbacc" type="stanza">
#             4.
#             <lb></lb>
# <l>Bey dem guͤnſtigem Suͤd-weſten<lb></lb> ſchweer’ ichs/ Teleſille/ dir:</l>
# <lb></lb>
# <l>dein verbleib’ ich fuͤr und fuͤr.<lb></lb>
# <fw place="bottom" type="sig">M iiij</fw><fw place="bottom" type="catch">Gib</fw><lb></lb>
# <pb facs="#f0274" n="224"></pb>
# <fw place="top" type="header"><hi rendition="#b">Geharnſchter Venus</hi></fw></l>
# <lb></lb>
# <l>Gib mein Schiff den Felſen-aͤſten/</l>
# <lb></lb>
# <l>Zeſyrs-Bruder wo ich liege.</l>
# <lb></lb>
# <l>und mein liebſtes Kind betriege!</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabccb
# lines:
# ['jch hielt au scherz ein liebes kind umfangen', 'gen', 'die eyfersucht verfärbte mund und wau', 'als sie di spiel von ungesehr ersach', 'hätt eyfer nicht den eyfer lassen sehen', 'ich würde nicht so wol mit buschgen stehen', 'nu wird es ernst was vor au scherzgeschach']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="aabccb" type="stanza">
# <hi rendition="#aq">III.</hi>
# <lb></lb>
# <l>Jch hielt’ auß Scherz ein liebes Kind umfan-<lb></lb>
# <hi rendition="#et">gen/</hi></l>
# <l prev="#v17" xml:id="v18"><hi rendition="#et">(gen/</hi></l>
# <lb></lb>
# <l next="#v18" xml:id="v17">die Eyfer-ſucht verfaͤrbte Mund und Wau-</l>
# <lb></lb>
# <l>als ſie diß Spiel von ungeſehr erſach.</l>
# <lb></lb>
# <l>Haͤtt’ Eyfer nicht den Eyfer laſſen ſehen/</l>
# <lb></lb>
# <l>ich wuͤrde nicht ſo wol mit Buſchgen ſtehen/</l>
# <lb></lb>
# <l>Nu wird es Ernſt/ was vor auß Scherz<lb></lb>
# <hi rendition="#et">geſchach.</hi></l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabccb
# lines:
# ['auff rede folget wiederrede', 'kein weibesbild ist je so blöde', 'die auff den grunicht danken soltalslezteres zehen', 'alsdenn hält ja die zunge feste so tuht ein süsser blikk das beste', 'und zeuget was das herz gewollt']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="3" rhyme="aabccb" type="stanza">
#             3.
#             <lb></lb>
# <l>Auff Rede folget Wieder-rede.</l>
# <lb></lb>
# <l>Kein Weibes-bild iſt je ſo bloͤde/</l>
# <lb></lb>
# <l>die auff den Gruß-nicht danken ſolt’.<lb></lb>
# <fw place="bottom" type="catch">Als-</fw><lb></lb>
# <pb facs="#f0321" n="267"></pb>
# <fw place="top" type="header"><hi rendition="#b">Lezteres Zehen.</hi></fw></l>
# <lb></lb>
# <l>Alsdenn (haͤlt ja die Zunge feſte)<lb></lb> ſo tuht ein ſuͤſſer Blikk das beſte/</l>
# <lb></lb>
# <l>und zeuget/ was das Herz gewollt.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabccb
# lines:
# ['wer wird hastu mich umgebracht', 'alsdenn erheben deine macht', 'wer wird von deinen tahten singen', 'werd ich noch etwas übrig seinsogeharnschter venus so              bleibt die ehr alleine dein', 'mein staub kan dir nicht nuzzen bringen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="4" rhyme="aabccb" type="stanza">
#             4.
#             <lb></lb>
# <l>Wer wird/ haſtu mich umgebracht/</l>
# <lb></lb>
# <l>alsdenn erheben deine Macht?</l>
# <lb></lb>
# <l>Wer wird von deinen Tahten ſingen?</l>
# <lb></lb>
# <l>Werd’ ich noch etwas uͤbrig ſein:<lb></lb>
# <fw place="bottom" type="catch">ſ<supplied>o</supplied></fw><lb></lb>
# <pb facs="#f0142" n="102"></pb>
# <fw place="top" type="header"><hi rendition="#b">Geharnſchter Venus</hi></fw><lb></lb> ſo
#               bleibt die Ehr’ <supplied>a</supplied>lleine dein.</l>
# <lb></lb>
# <l>Mein Staub kan dir nicht Nuzzen brin-<lb></lb>
# <hi rendition="#et">gen?</hi></l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabcbc
# lines:
# ['mein sprach ich la mich doch zufrieden', 'die ursach wird nicht einem ieden so auff die nase hingehenkt so dürff              ichs auch nicht frey bekennen', 'wer alles sagt und wenig denkt', 'der kan sich deinen freund nicht nennen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="4" rhyme="aabcbc" type="stanza">
#             4.
#             <lb></lb>
# <l>Mein/ (ſprach ich) laß mich doch zufrieden/</l>
# <lb></lb>
# <l>die Urſach wird nicht einem ieden<lb></lb> ſo auff die Naſe hingehenkt/<lb></lb> ſo duͤrff
#               ichs auch nicht frey bekennen:</l>
# <lb></lb>
# <l>wer alles ſagt und wenig denkt/</l>
# <lb></lb>
# <l>der kan ſich deinen Freund nicht nennen.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabcbc
# lines:
# ['doch soll ichs zeitlieb dir entdekken', 'und nichts nicht untern stuel verstekkensozweytes zehen so gieb              mir feder und papier', 'jch wei es was ich mündlich sage', 'urteilestu wie ungebühr', 'als unrecht falsch und lügenklage']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="5" rhyme="aabcbc" type="stanza">
#             5.
#             <lb></lb>
# <l>Doch/ ſoll ichs/ Zeit-lieb/ dir entdekken/</l>
# <lb></lb>
# <l>und nichts nicht untern Stuel verſtekken<lb></lb>
# <fw place="bottom" type="catch">ſo</fw><lb></lb>
# <pb facs="#f0103" n="67"></pb>
# <fw place="top" type="header"><hi rendition="#b">Zweytes Zehen.</hi></fw><lb></lb> ſo gieb
#               mir Feder und Papier.</l>
# <lb></lb>
# <l>Jch weiß es was ich muͤndlich ſage</l>
# <lb></lb>
# <l>urteileſtu wie ungebuͤhr/</l>
# <lb></lb>
# <l>als Unrecht Falſch und Luͤgen-klage.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abab
# lines:
# ['wer mit kalisten wil vergünt in freudenleben', 'der mu kleandern sich verschweren alsein freund', 'ben', 'lysandern hätte nie das glükk ein solches ge', 'was er jo offt erhielt wer er kleandersfeind']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="abab" type="stanza">
# <hi rendition="#aq">XXX.</hi>
# <lb></lb>
# <l>Wer mit Kaliſten wil verguͤnt in Freuden<lb></lb>
# <hi rendition="#et">leben/</hi></l>
# <lb></lb>
# <l>Der muß Kleandern ſich verſchweren als<lb></lb>
# <hi rendition="#et">ein Freund.</hi></l>
# <l prev="#v19" xml:id="v20"><hi rendition="#et">(ben</hi></l>
# <lb></lb>
# <l next="#v20" xml:id="v19">Lyſandern haͤtte nie das Gluͤkk ein ſolches ge-</l>
# <lb></lb>
# <l>was er jo offt erhielt/ Wer er Kleanders<lb></lb>
# <hi rendition="#et">Feind.</hi></l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbacc
# lines:
# ['wenn mich mein kind wil traurig sehn', 'und blut au meinem herzen pressen so spricht sie du wirst mich vergessen              so bald du wirst von hinnen gehn', 'sag rosilis ach meine fromme', 'woher dir doch der argwohn komme']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="1" rhyme="abbacc" type="stanza">
#             1.
#             <lb></lb>
# <l><hi rendition="#in">W</hi>Enn mich mein Kind wil traurig ſehn</l>
# <lb></lb>
# <l>und Blut auß meinem Herzen preſſen<lb></lb> ſo ſpricht ſie: Du wirſt mich vergeſſen<lb></lb>
#               ſo bald du wirſt von hinnen gehn.</l>
# <lb></lb>
# <l>Sag/ Roſilis/ Ach! meine Fromme:</l>
# <lb></lb>
# <l>Woher dir doch der Argwohn komme.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbacc
# lines:
# ['kein einger mund hat mich gerührt seit ich den deinen dürffen herzen', 'hastu mich wo mit einer scherzengesehngeharnschter venus', 'gesehn wor heucheley gespürt', 'die ader wolt ich au mir reissen', 'und selber vor die hunde schmeissen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="4" rhyme="abbacc" type="stanza">
#             4.
#             <lb></lb>
# <l>Kein einger Mund hat mich geruͤhrt<lb></lb> ſeit ich den deinen duͤrffen herzen.</l>
# <lb></lb>
# <l>Haſtu mich wo mit einer ſcherzen<lb></lb>
# <fw place="bottom" type="catch">geſehn?</fw><lb></lb>
# <pb facs="#f0066" n="34"></pb>
# <fw place="top" type="header"><hi rendition="#b">Geharnſchter Venus</hi></fw></l>
# <lb></lb>
# <l>geſehn? Wor Heucheley geſpuͤrt?</l>
# <lb></lb>
# <l>Die Ader wolt’ ich auß mir reiſſen</l>
# <lb></lb>
# <l>und ſelber vor die Hunde ſchmeiſſen.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbacc
# lines:
# ['jch bin und werd auch ewig sein', 'wie ich mich einmahl dir versprochen', 'mein eyd verbleibet unzerbrochen solt auch der himmel fallen ein', 'die erde nimmer feste stehen', 'und alles drunt und drüber gehen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="5" rhyme="abbacc" type="stanza">
#             5.
#             <lb></lb>
# <l>Jch bin und werd’ auch ewig ſein</l>
# <lb></lb>
# <l>wie ich mich einmahl dir verſprochen/</l>
# <lb></lb>
# <l>mein Eyd verbleibet unzerbrochen/<lb></lb> ſolt’ auch der Himmel fallen ein/</l>
# <lb></lb>
# <l>die Erde nimmer feſte ſtehen</l>
# <lb></lb>
# <l>und alles drunt- und druͤber gehen.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbacc
# lines:
# ['so wei es doch mein herz allein', 'mein herz da dich sonst keine kennet', 'und nur in deinen flammen brennet', 'da du die einige wirst sein', 'die bi der tod mich auffwird reiben soll meiner seelen seele bleiben']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="7" rhyme="abbacc" type="stanza">
#             7.
#             <lb></lb>
# <l>So weiß es doch mein Herz allein/</l>
# <lb></lb>
# <l>mein Herz/ daß dich/ ſonſt keine kennet/</l>
# <lb></lb>
# <l>und nur in deinen Flammen brennet/</l>
# <lb></lb>
# <l>daß du die einige wirſt ſein/</l>
# <lb></lb>
# <l>die/ biß der Tod mich auff-wird reiben/<lb></lb> ſoll meiner Seelen Seele bleiben.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabcbc
# lines:
# ['so lieblich sahe nie dione', 'wenn sie auff dem vergöldtem trohned ijingeharnschter venus', 'in pasos tempel ehr empfieng', 'betracht ich dein besütes wesen so halt ich für ein schlechtes ding', 'was ich von helenen gelesen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="2" rhyme="aabcbc" type="stanza">
#             2.
#             <lb></lb>
# <l>So lieblich ſahe nie Dione</l>
# <lb></lb>
# <l>wenn ſie auff dem vergoͤldtem Trohne<lb></lb>
# <fw place="bottom" type="sig">D ij</fw><fw place="bottom" type="catch">in</fw><lb></lb>
# <pb facs="#f0078" n="42"></pb>
# <fw place="top" type="header"><hi rendition="#b">Geharnſchter Venus</hi></fw></l>
# <lb></lb>
# <l>in Paſos Tempel Ehr’ empfieng!</l>
# <lb></lb>
# <l>Betracht’ ich dein beſuͤßtes Weſen/<lb></lb> ſo halt’ ich fuͤr ein ſchlechtes Ding/</l>
# <lb></lb>
# <l>was ich von Helenen geleſen.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabcbc
# lines:
# ['wie heuffig aber dich mit gaben', 'vor andern die gebuhrt erhaben so kärglich ist dir mitgeteilt', 'mitleiden trost und ein gemühte', 'da eine wunde seele heilt', 'durch freundes zuspruch gunst und güte']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="4" rhyme="aabcbc" type="stanza">
#             4.
#             <lb></lb>
# <l>Wie heuffig aber dich mit Gaben</l>
# <lb></lb>
# <l>vor andern die Gebuhrt erhaben:<lb></lb> ſo kaͤrglich iſt dir mitgeteilt.</l>
# <lb></lb>
# <l>Mit-Leiden/ Troſt/ und ein Gemuͤhte/</l>
# <lb></lb>
# <l>daß eine wunde Seele heilt</l>
# <lb></lb>
# <l>durch Freundes Zuſpruch/ Gunſt und Guͤte.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabcbc
# lines:
# ['so meinstu du seyst dir gebohren seyst dir allein zum zwekk erkohren', 'warum wir auff der erde seyn', 'kein bild wird darum wol gemahlet', 'da man es birget in den schrein so wird die arbeit nicht bezahlet']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="7" rhyme="aabcbc" type="stanza">
#             7.
#             <lb></lb>
# <l>So meinſtu/ du ſeyſt dir gebohren/<lb></lb> ſeyſt dir allein zum Zwekk erkohren</l>
# <lb></lb>
# <l>warum wir auff der Erde ſeyn.</l>
# <lb></lb>
# <l>Kein Bild wird darum wol gemahlet</l>
# <lb></lb>
# <l>daß man es birget in den Schrein<lb></lb> ſo wird die Arbeit nicht bezahlet.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabcbc
# lines:
# ['die grausamkeit und süsses lachen', 'wie können die verwandnüs machen', 'in einem schönem angesichtd iijentgeharnschter venus', 'entwehn dich kind der ernstgebehrden so wird der schönen schönheit              licht', 'noch tausendfach verschönert werden']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="9" rhyme="aabcbc" type="stanza">
#             9.
#             <lb></lb>
# <l>Die Grauſamkeit und ſuͤſſes lachen</l>
# <lb></lb>
# <l>wie koͤnnen die Verwandnuͤs machen</l>
# <lb></lb>
# <l>in einem ſchoͤnem Angeſicht’?<lb></lb>
# <fw place="bottom" type="sig">D iij</fw><fw place="bottom" type="catch">Ent-</fw><lb></lb>
# <pb facs="#f0080" n="44"></pb>
# <fw place="top" type="header"><hi rendition="#b">Geharnſchter Venus</hi></fw></l>
# <lb></lb>
# <l>Entwehn dich/ Kind/ der Ernſt-gebehrden/<lb></lb> ſo wird der ſchoͤnen Schoͤnheit
#               Licht</l>
# <lb></lb>
# <l>noch tauſendfach verſchoͤnert werden.</l>
# </lg>
# ######## error #########
# rhyme:
# ababcc
# lines:
# ['jch sehe vor mir blut und staub', 'und tausent mann gewaffnet liegen', 'ich sehe wie auff sieg und raub so viel vergöldte fahnen fliegen', 'doch brenn ich wer nicht brennen kan', 'fang ein berühmter wesen an']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="2" rhyme="ababcc" type="stanza">
#             2.
#             <lb></lb>
# <l>Jch ſehe vor mir Blut und Staub/</l>
# <lb></lb>
# <l>und tauſent Mann gewaffnet liegen/</l>
# <lb></lb>
# <l>ich ſehe/ wie auff Sieg und Raub<lb></lb> ſo viel vergoͤldte Fahnen fliegen<hi rendition="#i">:</hi></l>
# <lb></lb>
# <l>doch brenn’ ich. Wer nicht brennen kan/</l>
# <lb></lb>
# <l>fang’ ein beruͤhmter Weſen an.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababcc
# lines:
# ['jch hätte die gelegenheit', 'ein neues jlium zumelden', 'es gibt mir anla mancher streit so vieler ritterlichen helden', 'doch brenn ich wer nicht brennen kan', 'fang ein berühmter wesen an']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="4" rhyme="ababcc" type="stanza">
#             4.
#             <lb></lb>
# <l>Jch haͤtte die Gelegenheit</l>
# <lb></lb>
# <l>ein neues Jlium zumelden:</l>
# <lb></lb>
# <l>Es gibt mir Anlaß mancher Streit<lb></lb> ſo vieler ritterlichen Helden:</l>
# <lb></lb>
# <l>Doch brenn’ ich. Wer nicht brennen kan/</l>
# <lb></lb>
# <l>fang’ ein beruͤhmter Weſen an.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababcc
# lines:
# ['was mir die venus predigt ein samt ihrem lieblichem empusen', 'mag meines nahmens lorber sein', 'sonst brauch ich keiner andern musen', 'jch brenne wer nicht brennen kan', 'fang ein berühmter wesen an']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="7" rhyme="ababcc" type="stanza">
#             7.
#             <lb></lb>
# <l>Was mir die Venus predigt ein<lb></lb> ſamt ihrem lieblichem Empuſen/</l>
# <lb></lb>
# <l>mag meines Nahmens Lorber ſein<hi rendition="#i">:</hi></l>
# <lb></lb>
# <l>Sonſt brauch’ ich keiner andern Muſen.</l>
# <lb></lb>
# <l>Jch brenne. Wer nicht brennen kan/</l>
# <lb></lb>
# <l>fang’ ein beruͤhmter Weſen an.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbaccdede
# lines:
# ['wärt ihr kinder guter ehren scheutet ihr so nicht', 'des klaren tages licht', 'die dem dunklem angehören', 'bleiben wie sie sein', 'ohn tugendlicht und schein', 'unsrer liebe göldnes feuer stekkt sich in die winkel nicht steigt empor              und blizzet freyer', 'als die lästerkohle sicht']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="2" rhyme="abbaccdede" type="stanza">
#             2.
#             <lb></lb>
# <l>Waͤrt ihr Kinder guter Ehren<lb></lb> ſcheutet ihr ſo nicht</l>
# <lb></lb>
# <l>des klaren Tages Licht.</l>
# <lb></lb>
# <l>Die dem dunklem angehoͤren</l>
# <lb></lb>
# <l>bleiben/ wie ſie ſein</l>
# <lb></lb>
# <l>ohn Tugend-Licht und Schein.</l>
# <lb></lb>
# <l>Unſrer Liebe goͤldnes Feuer<lb></lb> ſtekkt ſich in die Winkel nicht/<lb></lb> ſteigt empor
#               und blizzet freyer</l>
# <lb></lb>
# <l>als die Laͤſter-kohle ſicht.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbaccdede
# lines:
# ['nun ihr rauch und qwalmverwanten', 'eure russigkeit', 'bezeuget wer ihr seid', 'weicht und sucht die euch bekanten so die nebellufft', 'erhält in pluto grufft', 'euers schwefels angezünde', 'wird euch mindern schlaff und ruh', 'unsrer liebe westenwinde', 'wehn uns göldne straalen zu']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="3" rhyme="abbaccdede" type="stanza">
#             3.
#             <lb></lb>
# <l>Nun ihr Rauch und Qwalm-Verwanten</l>
# <lb></lb>
# <l>Eure Ruſſigkeit</l>
# <lb></lb>
# <l>bezeuget wer ihr ſeid.</l>
# <lb></lb>
# <l>Weicht und ſucht die euch Bekanten<lb></lb> ſo die Nebel-Lufft</l>
# <lb></lb>
# <l>erhaͤlt in Pluto Grufft.</l>
# <lb></lb>
# <l>Euers Schwefels Angezuͤnde</l>
# <lb></lb>
# <l>wird euch mindern Schlaff und Ruh</l>
# <lb></lb>
# <l>Unſrer Liebe Weſten-Winde</l>
# <lb></lb>
# <l>wehn uns goͤldne Straalen zu.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababcc
# lines:
# ['pakket euch ihr pierinnen', 'wo ihr mir nicht helffen könnt', 'föbus pallas weicht von hinnen', 'nicht ein blikk sey euch vergönnt', 'wo nicht euer reimenzwingen sie zur gunst vermag zu bringen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="1" rhyme="ababcc" type="stanza">
#             1.
#             <lb></lb>
# <l><hi rendition="#in">P</hi>Akket euch/ ihr Pierinnen/</l>
# <lb></lb>
# <l>wo ihr mir nicht helffen koͤnnt!</l>
# <lb></lb>
# <l>Foͤbus/ Pallas/ weicht von hinnen/</l>
# <lb></lb>
# <l>nicht ein Blikk ſey Euch vergoͤnnt!</l>
# <lb></lb>
# <l>wo nicht euer Reimen-zwingen<lb></lb> ſie zur Gunſt vermag zu bringen.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababcc
# lines:
# ['eitle feder sey zerstossen sey verflucht verlacht papier', 'nu mich kloris augeschlossen', 'nüzzt mir keiner verse zier', 'nu der geiz sie hat verblendet', 'ist mein dichterwerk geschändet']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="2" rhyme="ababcc" type="stanza">
#             2.
#             <lb></lb>
# <l>Eitle Feder/ ſey zerſtoſſen/<lb></lb> ſey verflucht/ verlacht Papier!</l>
# <lb></lb>
# <l>Nu mich Kloris außgeſchloſſen/</l>
# <lb></lb>
# <l>nuͤzzt mir keiner Verſe Zier.</l>
# <lb></lb>
# <l>Nu der Geiz ſie hat verblendet<hi rendition="#i">:</hi></l>
# <lb></lb>
# <l>iſt mein Dichterwerk geſchaͤndet.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababcc
# lines:
# ['daher ist die hoffart kommen', 'daher hat der grimme neid seinen anfang erst genommen', 'darum ward zur abendzeit', 'erst die harte tühr verschlossen', 'und ein armer augestossen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="6" rhyme="ababcc" type="stanza">
#             6.
#             <lb></lb>
# <l>Daher iſt die Hoffart kommen</l>
# <lb></lb>
# <l>daher hat der grimme Neid<lb></lb> ſeinen Anfang erſt genommen/</l>
# <lb></lb>
# <l>darum ward zur Abend-Zeit</l>
# <lb></lb>
# <l>erſt die harte Tuͤhr verſchloſſen</l>
# <lb></lb>
# <l>und ein Armer außgeſtoſſen.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababcc
# lines:
# ['aber du der du mit gaben', 'mich verliebten stössest au', 'feuer wind und diebesraben stürzen dein hochprangend hau', 'bi es möge gleich der erden', 'und mit dir vertilget werden']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="8" rhyme="ababcc" type="stanza">
#             8.
#             <lb></lb>
# <l>Aber du/ der du mit Gaben</l>
# <lb></lb>
# <l>mich Verliebten ſtoͤſſeſt auß/</l>
# <lb></lb>
# <l>Feuer/ Wind und Diebes-Raben<lb></lb> ſtuͤrzen dein hochprangend Hauß</l>
# <lb></lb>
# <l>biß es moͤge gleich der Erden</l>
# <lb></lb>
# <l>und mit dir vertilget werden!</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababccdd
# lines:
# ['zwar bin ich schlechter mensch nicht wehrt', 'da ihr der schönen mein etwegen', 'ein einig seuffzgen nur entfährt sich mög ein trähnentröpschen regeng iijdochgeharnschter venus drittes                  zehen', 'doch wil ich schweren da sie sich', 'mehr qwält und ängstigt weder ich', 'ach möcht ich doch nur bey ihr stehen', 'und ihr betrübnis anmit sehen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="6" rhyme="ababccdd" type="stanza">
#             6.
#             <lb></lb>
# <l>Zwar bin ich ſchlechter Menſch nicht wehrt/</l>
# <lb></lb>
# <l>daß ihr/ der Schoͤnen/ mein etwegen</l>
# <lb></lb>
# <l>ein einig Seuffzgen nur entfaͤhrt<lb></lb> ſich moͤg’ ein Traͤhnen-troͤpſchen regen:<lb></lb>
# <fw place="bottom" type="sig">G iij</fw><fw place="bottom" type="catch">Doch</fw><lb></lb>
# <pb facs="#f0152" n="112"></pb>
# <fw place="top" type="header"><hi rendition="#b">Geharnſchter Ven

# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="1" rhyme="aabbcdcd" type="stanza">
#             1.
#             <lb></lb>
# <l><hi rendition="#et">Die Nacht</hi></l>
# <lb></lb>
# <l>die ſonſt den Buhlern fuͤgt und ſuͤſſe Hoffnung mach<supplied>t</supplied><lb></lb>
# <hi rendition="#et">Die Ruh/</hi></l>
# <lb></lb>
# <l>die einem Liebendem ſagt alle Wolluſt zu/</l>
# <lb></lb>
# <l>bringt mir nur lauter Schmerzen</l>
# <lb></lb>
# <l>und raubet mir das Licht/</l>
# <lb></lb>
# <l>das meinem truͤben Herzen</l>
# <lb></lb>
# <l>des Troſtes Straal verſpricht.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbcdcd
# lines:
# ['der tag', 'dem sonst kein pafoskind recht günstig werden magdie gluht', 'der göldnen strahlen die der venus schaden tuhtf iiijergeharnschter venus', 'erteilt mir lauter freuden', 'und gönnet mir das glükk', 'die augen satt zu weiden', 'in meiner liebsten blikk']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="2" rhyme="aabbcdcd" type="stanza">
#             2.
#             <lb></lb>
# <l><hi rendition="#et">Der Tag</hi></l>
# <lb></lb>
# <l>dem ſonſt kein Pafos-kind recht guͤnſtig werden mag<lb></lb>
# <hi rendition="#et">Die Gluht</hi></l>
# <lb></lb>
# <l>der goͤldnen Strahlen/ die der Venus ſchaden tuht.<lb></lb>
# <fw place="bottom" type="sig">F iiij</fw><fw place="bottom" type="catch">Er-</fw><lb></lb>
# <pb facs="#f0130" n="90"></pb>
# <fw place="top" type="header"><hi rendition="#b">Geharnſchter Venus</hi></fw></l>
# <lb></lb>
# <l>Erteilt mir lauter Freuden</l>
# <lb></lb>
# <l>und goͤnnet mir das Gluͤkk</l>
# <lb></lb>
# <l>die Augen ſatt zu weiden</l>
# <lb></lb>
# <l>in meiner Liebſten Blikk.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbcdcd
# lines:
# ['wenn iezt', 'apollens feuergold der berge haubt erhizztund nu', 'die auffgewekkte welt entsaget ihrer ruh', 'rührt mich rosillen wange', 'mit einem feuchten ku', 'und dieses währt so lange', 'bi auff den hesperus']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="3" rhyme="aabbcdcd" type="stanza">
#             3.
#             <lb></lb>
# <l><hi rendition="#et">Wenn iezt</hi></l>
# <lb></lb>
# <l>Apollens Feuer-gold der Berge Haubt erhizzt.<lb></lb>
# <hi rendition="#et">Und nu</hi></l>
# <lb></lb>
# <l>die auffgewekkte Welt entſaget ihrer Ruh:</l>
# <lb></lb>
# <l>ruͤhrt mich Roſillen Wange</l>
# <lb></lb>
# <l>mit einem feuchten Kuß’</l>
# <lb></lb>
# <l>und dieſes waͤhrt ſo lange</l>
# <lb></lb>
# <l>biß auff den Heſperus.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbcdcd
# lines:
# ['so bald', 'der sonnen kerze wird in thetis schosse kaltlaton', 'in düstrer wolkenlufft führt auff den bleichen mohn so weicht mein licht von              hinnen', 'denn wird mir erst die nacht', 'das kind der erebinnen', 'zur rechten nacht gemacht']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="4" rhyme="aabbcdcd" type="stanza">
#             4.
#             <lb></lb>
# <l><hi rendition="#et">So bald</hi></l>
# <lb></lb>
# <l>der Sonnen Kerze wird in Thetis Schoſſe kalt<lb></lb>
# <hi rendition="#et">Laton’</hi></l>
# <lb></lb>
# <l>in duͤſtrer Wolken-Lufft fuͤhrt auff den bleichen Mohn<lb></lb> ſo weicht mein Licht von
#               hinnen</l>
# <lb></lb>
# <l>denn wird mir erſt die Nacht</l>
# <lb></lb>
# <l>das Kind der Erebinnen</l>
# <lb></lb>
# <l>zur rechten Nacht gemacht.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbcdc
# lines:
# ['drum geh', 'verhates sternenheer gleich nimer au der seekomm an', 'geliebter lucifer tritt auff olympens bahn', 'der tag der mich so liebet soll meine freude sein', 'die nacht die mich betrübet', 'weich in die höll hin ein']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="5" rhyme="aabbcdc" type="stanza">
#             5.
#             <lb></lb>
# <l><hi rendition="#et">Drum geh</hi></l>
# <lb></lb>
# <l>verhaßtes Sternen-Heer gleich nim̃er auß der See.<lb></lb>
# <hi rendition="#et">Komm an/</hi></l>
# <lb></lb>
# <l>geliebter Lucifer tritt auff Olympens Bahn.</l>
# <lb></lb>
# <l>Der Tag der mich ſo liebet/<lb></lb> ſoll meine Freude ſein.</l>
# <lb></lb>
# <l>Die Nacht/ die mich betruͤbet/</l>
# <lb></lb>
# <l>weich’ in die Hoͤll’ hin ein.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbcddc
# lines:
# ['so schrie er bi er zu der hütte kahme', 'da wo seine mele die füsse ruh einnahme', 'kaum rührt er an den riegel bey der tühr so wischte mopsa vom stroh              herfür', 'werklopffet an so langsam schon nach mitternacht', 'mach mägdchen auf ja bald hätt ich auf gemachteyviertes zeheney ja', 'wer ist denn da', 'hastu nicht acht']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="2" rhyme="aabbcddc" type="stanza">
#             2.
#             <lb></lb>
# <l>So ſchrie er biß er zu der Huͤtte kahme/</l>
# <lb></lb>
# <l>da/ wo ſeine Mele die fuͤſſe Ruh einnahme.</l>
# <lb></lb>
# <l>Kaum ruͤhrt’ er an den Riegel bey der Tuͤhr/<lb></lb> ſo wiſchte Mopſa vom Stroh
#               herfuͤr:</l>
# <lb></lb>
# <l>Werklopffet an ſo langſam ſchon nach Mitternacht?</l>
# <lb></lb>
# <l>Mach/ Maͤgdchen auf! Ja/ bald haͤtt’ ich auf gemacht.<lb></lb>
# <fw place="bottom" type="catch">Ey</fw><lb></lb>
# <pb facs="#f0175" n="131"></pb>
# <fw place="top" type="header"><hi rendition="#b">Viertes Zehen.</hi></fw><lb></lb>
# <hi rendition="#et">Ey ja.</hi></l>
# <lb></lb>
# <l>Wer iſt denn da?</l>
# <lb></lb>
# <l>haſtu nicht acht?</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbcddc
# lines:
# ['was meinstu so zu bergen deine tükke', 'sag mit wehme triebstu vor der tühr so schelmenstükke', 'ach herze frau wir sind verrahten hier', 'es ist ein mensche drau für der tühr', 'der klopffet an wil mit gewalt zu uns herein spricht oridor bin ich mele              la mich einmacht auff', 'gebt achtung drauff', 'die stimm ist sein']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="6" rhyme="aabbcddc" type="stanza">
#             6.
#             <lb></lb>
# <l>Was? meinſtu ſo zu bergen deine Tuͤkke?</l>
# <lb></lb>
# <l>Sag mit wehme triebſtu vor der Tuͤhr ſo Schelmen-<lb></lb>
# <hi rendition="#et">ſtuͤkke.</hi></l>
# <lb></lb>
# <l>Ach herze Frau/ wir ſind verrahten hier/</l>
# <lb></lb>
# <l>es iſt ein Menſche drauß fuͤr der Tuͤhr/</l>
# <lb></lb>
# <l>der klopffet an/ wil mit Gewalt zu uns herein/<lb></lb> ſpricht: Oridor bin ich/ Mele/
#               laß mich ein.<lb></lb>
# <hi rendition="#et">Macht auff.</hi></l>
# <lb></lb>
# <l>Gebt Achtung drauff.</l>
# <lb></lb>
# <l>Die Stimm’ iſt ſein.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbcddc
# lines:
# ['still mit der tühr da nicht mein vaterhöre', 'und mir meine lust mit oridor auff heute wehre', 'ach frau er ists zünd ich den schorrstein an', 'da meine zahl ich auspinnen kan', 'schweig närrin nein iezt ist nicht licht noch spinnen noht', 'mein vater hat ja gott lob ohn di noch brodth iiijgehgeharnschter venusgeh vor', 'mein oridor sonst bin ich todt']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="10" rhyme="aabbcddc" type="stanza">
#             10.
#             <lb></lb>
# <l>Still mit der Tuͤhr? daß nicht mein Vaterhoͤre/</l>
# <lb></lb>
# <l>und mir meine Luſt mit Oridor auff heute wehre.</l>
# <lb></lb>
# <l>Ach Frau/ er iſts/ zuͤnd’ ich den Schorrſtein an</l>
# <lb></lb>
# <l>daß meine Zahl ich außſpinnen kan?</l>
# <lb></lb>
# <l>Schweig/ Naͤrrin/ nein iezt iſt nicht Licht noch ſpi<supplied>n-</supplied><lb></lb>
# <hi rendition="#et">nen noht/</hi></l>
# <lb></lb>
# <l>mein Vater hat ja Gott lob ohn diß noch Brodt.<lb></lb>
# <fw place="bottom" type="sig">H iiij</fw><fw place="bottom" type="catch">Ge<supplied>h</supplied></fw><lb></lb>
# <pb facs="#f0178" n="134"></pb>
# <fw place="top" type="header"><hi rendition="#b">Geharnſchter Venus</hi></fw><lb></lb>
# <hi rendition="#et">Geh vor/</hi></l>
# <lb></lb>
# <l>mein Oridor/<lb></lb> ſonſt bin ich todt.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbccddc
# lines:
# ['drauff trat er ein ein liebliches umfangen stillte beyder keusche lust und              ehrliches verlangen', 'und ob die nacht schon sonder monden war sie ganz all ein und ausser              gefahr', 'war doch ein ku genug zu leschen ihre brunst', 'die pallas hat so bewiesen lieb und gunstin zucht', 'wenn sie besucht', 'der gott der kunst']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="11" rhyme="aabbccddc" type="stanza">
#             11.
#             <lb></lb>
# <l>Drauff trat er ein. Ein liebliches umfangen<lb></lb> ſtillte beyder keuſche Luſt und
#               ehrliches Verlangen/</l>
# <lb></lb>
# <l>und ob die Nacht ſchon ſonder Monden war<lb></lb> ſie ganz all ein/ und auſſer
#               Gefahr/</l>
# <lb></lb>
# <l>war doch ein Kuß genug zu leſchen ihre Brunſt/</l>
# <lb></lb>
# <l>die Pallas hat ſo bewieſen Lieb und Gunſt/<lb></lb>
# <hi rendition="#et">in Zucht/</hi></l>
# <lb></lb>
# <l>wenn ſie beſucht</l>
# <lb></lb>
# <l>der Gott der Kunſt.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbccd
# lines:
# ['darum mein freund der du die nacht bedenkest', 'und auff ihre süsse lust die heisse sinnen lenkest sezz hier nicht ein des              lästers gelben zahn', 'sie haben nichts nicht iemahls getahn', 'das wieder zucht gebühr zula und tugendstreitt', 'sie liebten sich in der seltnen reinligkeitgleich wie', 'geschwister ie sich keusch erfreut']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="12" rhyme="aabbccd" type="stanza">
#             12.
#             <lb></lb>
# <l>Darum/ mein Freund/ der du die Nacht bedenkeſt/</l>
# <lb></lb>
# <l>und auff ihre ſuͤſſe Luſt die heiſſe Sinnen lenkeſt/<lb></lb> ſezz hier nicht ein des
#               Laͤſters gelben Zahn/</l>
# <lb></lb>
# <l>Sie haben nichts nicht iemahls getahn.</l>
# <lb></lb>
# <l>Das wieder Zucht/ Gebuͤhr/ Zulaß und Tugend<lb></lb>
# <hi rendition="#et">ſtreitt</hi></l>
# <lb></lb>
# <l>Sie liebten ſich in der ſeltnen Reinligkeit.<lb></lb>
# <hi rendition="#et">Gleich wie</hi></l>
# <lb></lb>
# <l>Geſchwiſter ie<lb></lb> ſich keuſch erfreut.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababcc
# lines:
# ['solt ich tausend stäte haben', 'fürchte mich der szyten land stünd ein königreich araben', 'und der nil in meiner hand', 'solt ich jndien beherschen', 'ehrte mich das reich der persen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="3" rhyme="ababcc" type="stanza">
#             3.
#             <lb></lb>
# <l>Solt’ ich tauſend Staͤte haben/</l>
# <lb></lb>
# <l>fuͤrchte mich der Szyten Land/<lb></lb> ſtuͤnd’ ein Koͤnigreich Araben</l>
# <lb></lb>
# <l>und der Nil’ in meiner Hand/</l>
# <lb></lb>
# <l>Solt’ ich Jndien beherſchen/</l>
# <lb></lb>
# <l>ehrte mich das Reich der Perſen:</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababcdcd
# lines:
# ['neäre hält sich wakker sie schmükt und schminket              sich', 'du alter knochenknakker', 'meinstu es sey vor dich', 'nein chremes la dich lehren', 'man pfleget also nicht', 'den husten zu verehren', 'was anders vor die gicht']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="1" rhyme="ababcdcd" type="stanza">
#             1.
#             <lb></lb>
# <l><hi rendition="#in">N</hi>Eaͤre haͤlt ſich wakker/<lb></lb> ſie ſchmuͤkt und ſchminket
#               ſich.</l>
# <lb></lb>
# <l>Du alter Knochen-knakker/</l>
# <lb></lb>
# <l>meinſtu/ es ſey vor dich?</l>
# <lb></lb>
# <l>Nein/ Chremes/ laß dich lehren:</l>
# <lb></lb>
# <l>Man pfleget alſo nicht</l>
# <lb></lb>
# <l>den Huſten zu verehren.</l>
# <lb></lb>
# <l>Was anders vor die Gicht.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababcdcd
# lines:
# ['und wäre sie voll runzeln', 'von schwarzbegeelter haut', 'beliebt als schweine schmunzeln', 'und wäre dir getraut so wäre sie zur frauen', 'dir dennoch viel zu schön', 'dem teufel möcht auch grauen', 'holz mit dir umzugehn']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="2" rhyme="ababcdcd" type="stanza">
#             2.
#             <lb></lb>
# <l>Und waͤre ſie voll Runzeln/</l>
# <lb></lb>
# <l>von ſchwarz-begeelter Haut</l>
# <lb></lb>
# <l>beliebt/ als Schweine ſchmunzeln</l>
# <lb></lb>
# <l>und waͤre dir getraut;<lb></lb> ſo waͤre ſie zur Frauen</l>
# <lb></lb>
# <l>dir dennoch viel zu ſchoͤn.</l>
# <lb></lb>
# <l>Dem Teufel moͤcht’ auch grauen/</l>
# <lb></lb>
# <l>Holz/ mit dir umzugehn.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbacc
# lines:
# ['wir singen fillis spielt die flöten', 'den schall merkt sie und ich allein', 'la fillis la dein fingern seyn sonst wirstu mich durch sehnsucht              tödten', 'soll aber ich die laute schlagen so wil ich wol ein stükkgen wagen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="abbacc" type="stanza">
# <hi rendition="#aq">XLI.</hi>
# <lb></lb>
# <l>Wir ſingen. Fillis ſpielt die Floͤten</l>
# <lb></lb>
# <l>den Schall merkt Sie und ich allein.</l>
# <lb></lb>
# <l>Laß/ Fillis/ laß dein Fingern ſeyn/<lb></lb> ſonſt wirſtu mich durch Sehn-ſucht
#               toͤdten.</l>
# <lb></lb>
# <l>Soll aber ich die Laute ſchlagen/<lb></lb> ſo wil ich wol ein Stuͤkkgen wagen.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbaba
# lines:
# ['es schmazzten vier korallenlippen', 'da dacht ich auff rosillen hin', 'dacht ich auff ihre lippen hin', 'als schmazzten vier korallen lippen', 'nein lauter rosen und rubin sind ihres roten mundes klippen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="2" rhyme="abbaba" type="stanza">
#             2.
#             <lb></lb>
# <l>Es ſchmazzten vier Korallen-Lippen/</l>
# <lb></lb>
# <l>da dacht’ ich auff Roſillen hin.</l>
# <lb></lb>
# <l>Dacht’ ich auff ihre Lippen hin/</l>
# <lb></lb>
# <l>als ſchmazzten vier Korallen Lippen</l>
# <lb></lb>
# <l>Nein. Lauter Roſen und Rubin<lb></lb> ſind ihres roten Mundes Klippen.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbaba
# lines:
# ['jch sach zwey liljenhände drükken so wei auch ist              rosillen hand', 'jst weisser nicht rosillen hand', 'wenn sie die meinen pflegt zu drükken', 'nicht schnee noch wolle hält bestand', 'für ihrer hände silberblikken']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="3" rhyme="abbaba" type="stanza">
#             3.
#             <lb></lb>
# <l>Jch ſach zwey Liljen-Haͤnde druͤkken<hi rendition="#i">!</hi><lb></lb> ſo weiß auch iſt
#               Roſillen Hand.</l>
# <lb></lb>
# <l>Jſt weiſſer nicht Roſillen Hand/</l>
# <lb></lb>
# <l>wenn ſie die meinen pflegt zu druͤkken?</l>
# <lb></lb>
# <l>Nicht Schnee noch Wolle haͤlt Beſtand</l>
# <lb></lb>
# <l>fuͤr ihrer Haͤnde ſilber-blikken.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbaba
# lines:
# ['es waren in dem busen hände', 'so treib ichs mit rosillen auch', 'mein leidet rosilis di auch', 'und lät darinnen deine hände', 'rosill hat dieses nicht im brauch so wende nu dein rühmen wende']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="5" rhyme="abbaba" type="stanza">
#             5.
#             <lb></lb>
# <l>Es waren in dem Buſen Haͤnde:</l>
# <lb></lb>
# <l>So treib’ ichs mit Roſillen auch.</l>
# <lb></lb>
# <l>Mein! leidet Roſilis diß auch/</l>
# <lb></lb>
# <l>und laͤßt darinnen deine Haͤnde?</l>
# <lb></lb>
# <l>Roſill’ hat dieſes nicht im Brauch/<lb></lb> ſo wende nu dein Ruͤhmen/ wende.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbaba
# lines:
# ['sie sahen sich beyd an und lachten so dacht ich lacht die rosilis', 'wer sagt was von der rosilis', 'wie ich und sie zusammen lachten', 'ja wenn ich koridon schon hie spräch ich es nicht sie zu verachten']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="6" rhyme="abbaba" type="stanza">
#             6.
#             <lb></lb>
# <l>Sie ſahen ſich beyd’ an und lachten:<lb></lb> ſo/ dacht’ ich/ lacht die Roſilis.</l>
# <lb></lb>
# <l>Wer ſagt was von der Roſilis/</l>
# <lb></lb>
# <l>wie ich und Sie zuſammen lachten?</l>
# <lb></lb>
# <l>Ja/ wenn ich Koridon ſchon hieß/<lb></lb> ſpraͤch’ ich es nicht/ ſie zu verachten.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbaba
# lines:
# ['es war nur ein gemüht in zweyen so ist die rosilis gesinnt', 'ja freylich ist sie so gesinnt', 'es lebt nur ein geist in uns zweyen', 'ach sollt ich rosilis mein kind', 'darüber mich nicht herzlich freuen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="7" rhyme="abbaba" type="stanza">
#             7.
#             <lb></lb>
# <l>Es war nur ein Gemuͤht in zweyen:<lb></lb> ſo iſt die Roſilis geſinnt.</l>
# <lb></lb>
# <l>Ja/ freylich/ iſt ſie ſo geſinnt/</l>
# <lb></lb>
# <l>es lebt nur ein Geiſt in uns Zweyen.</l>
# <lb></lb>
# <l>Ach<hi rendition="#i">!</hi> ſollt’ ich Roſilis/ mein Kind/</l>
# <lb></lb>
# <l>daruͤber mich nicht herzlich freuen.</l>
# </lg>
# ######## error #########
# rhyme:
# abbacc
# lines:
# ['als ich auf meiner liebsten mundach sanfte ruhstat brünstig lageund meiner schmerzen herbe plageihr täht au ganzem herzen kundwiegeharnschter venus', 'wie ich so oft um ihrentwegen', 'ruhtrostund sinnenohn gelegen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Stieler_Kasparvon_1660_gold_p63_s282_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="1" rhyme="abbacc" type="stanza">
#             1.
#             <lb></lb>
# <l><hi rendition="#in">A</hi>Ls ich auf meiner Liebſten Mund<lb></lb>
# <supplied>(a</supplied>ch ſanfte Ruhſtat!) bruͤnſtig lage<lb></lb>
# <supplied>un</supplied>d meiner Schmerzen herbe Plage<lb></lb>
# <supplied>ih</supplied>r taͤht’ auß ganzem Herzen kund/<lb></lb>
# <fw place="bottom" type="catch">wie</fw><lb></lb>
# <pb facs="#f0046" n="14"></pb>
# <fw place="top" type="header"><hi rendition="#b">Geharnſchter Venus</hi></fw></l>
# <lb></lb>
# <l>wie ich ſo oft um ihrentwegen</l>
# <lb></lb>
# <l>Ruh-troſt-und Sinnen-ohn gelegen.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# abbacc
# lines:
# ['ach frage nicht nach meiner gluht sprach ich was              frischer ey und winde sind meiner flammen angezünde', 'du weist es wie auf jener fluht', 'von kalter norden luft gestanden', 'ich lag in deiner arme banden']
# file:
# ...
# <lb></lb>
# <l>Der du traͤgſt zuͤchtiger hoͤher Gemuͤt,</l>
# <lb></lb>
# <l>Als Fuͤrſten und Grafen aus hohem Gebluͤt!</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabb
# lines:
# ['und führt ihn durch dornen und nessel und stein', 'in einen zertrümmerten keller hinein', 'hier flimmert ein lämpchen es zog ihn entlang', 'beim schimmer des lämpchens den heimlichen', 'gang ']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/BБrger_GottfriedAugust_1778_gold_p34_s360_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="17" rhyme="aabb" type="stanza">
# <l>Und fuͤhrt’ ihn, durch Dornen und Neſſel und Stein,</l>
# <lb></lb>
# <l>In einen zertruͤmmerten Keller hinein.</l>
# <lb></lb>
# <l>Hier flimmert’ ein Laͤmpchen; es zog ihn entlang,</l>
# <lb></lb>
# <l>Beim Schimmer des Laͤmpchens, den heimlichen</l>
# <lb></lb>
# <l>Gang. —</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabb
# lines:
# ['und kamen wol vor die verborgene thür', 'und standen und harten und lauschten alhier', 'horch könig da flüsterts  horch könig da', 'sprichts ', 'da glaubest du noch nicht so glaubest du nichts']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/BБrger_GottfriedAugust_1778_gold_p34_s360_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="32" rhyme="aabb" type="stanza">
# <l>Und kamen wol vor die verborgene Thuͤr,</l>
# <lb></lb>
# <l>Und ſtanden und harten und lauſchten alhier:</l>
# <lb></lb>
# <l>„Horch Koͤnig! da fluͤſterts — Horch Koͤnig! da</l>
# <lb></lb>
# <l>ſprichts. —</l>
# <lb></lb>
# <l>Da! glaubeſt du noch nicht, ſo glaubeſt du nichts.„</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabb
# lines:
# ['nein las mich der hahn hat zum morgen', 'gekräht', 'schon leuchtet der morgen die morgenluft weht', 'schon wirbelt die schwalbe den morgengesang', 'oh las mich wie wird mir ums herze so bang  ']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/BБrger_GottfriedAugust_1778_gold_p34_s360_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="50" rhyme="aabb" type="stanza">
# <l>„Nein! Las mich! Der Hahn hat zum Morgen</l>
# <lb></lb>
# <l>gekraͤht;</l>
# <lb></lb>
# <l>Schon leuchtet der Morgen; die Morgenluft weht;</l>
# <lb></lb>
# <l>Schon wirbelt die Schwalbe den Morgengeſang,</l>
# <lb></lb>
# <l>Oh! Las mich! Wie wird mir um’s Herze ſo bang!„ ‒ ‒</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabb
# lines:
# ['ach süsser   leb wol dann   nein bleib', 'noch   ade  ', 'o weh mir wie thuts mir im busen so weh  ', 'weis her mir dein herzchen   ach pocht ja so sehr  ', 'hab lieb mich du herzchen auf morgen nacht', 'mehr ']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/BБrger_GottfriedAugust_1778_gold_p34_s360_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="51" rhyme="aabb" type="stanza">
# <l>„Ach Suͤſſer! ‒ ‒ Leb wol dann! ‒ ‒ Nein bleib</l>
# <lb></lb>
# <l>noch! ‒ ‒ Ade! ‒ ‒</l>
# <lb></lb>
# <l>O weh mir! Wie thut’s mir im Buſen ſo weh! ‒ ‒</l>
# <lb></lb>
# <l>Weis her mir dein Herzchen! ‒ ‒ Ach! pocht ja ſo ſehr! ‒ ‒</l>
# <lb></lb>
# <l>Hab lieb mich, du Herzchen! Auf Morgen Nacht</l>
# <lb></lb>
# <l>mehr!„ —</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabb
# lines:
# ['der prinz von hispania schäumend vor wut', 'zerhieb ihm den busen mit knirschendem mut', 'weis her mir dein herzchen ach pocht ja so sehr ', 'hast lieb gehabt herzchen habs morgen nacht', 'mehr']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/BБrger_GottfriedAugust_1778_gold_p34_s360_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="55" rhyme="aabb" type="stanza">
# <l>Der Prinz von Hiſpania, ſchaͤumend vor Wut,</l>
# <lb></lb>
# <l>Zerhieb ihm den Buſen mit knirſchendem Mut:</l>
# <lb></lb>
# <l>„Weis her mir dein Herzchen! Ach! pocht ja ſo ſehr! —</l>
# <lb></lb>
# <l>Haſt lieb gehabt, Herzchen? Hab’s Morgen Nacht</l>
# <lb></lb>
# <l>mehr!„</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabb
# lines:
# ['und ris ihm vom busen das zuckende herz', 'und kühlte sein mütchen mit gräslichem scherz', 'da hab ich dich herzchen ach pochst ja so sehr', 'hab lieb nun du herzchen habs morgen nacht', 'mehr ']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/BБrger_GottfriedAugust_1778_gold_p34_s360_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n

# file:
# <_io.TextIOWrapper name='rhyme_corpus/BБrger_GottfriedAugust_1778_gold_p34_s360_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="1" rhyme="aabb" type="stanza">
# <l><hi rendition="#in">A</hi>uf, Maienluͤftchen, aus den Blumenbe-</l>
# <lb></lb>
# <l>ten!</l>
# <lb></lb>
# <l>Wo deine Kuͤſſe Florens Toͤchter roͤten;</l>
# <lb></lb>
# <l>Wo du ſo liebetraulich allen heuchelſt,</l>
# <lb></lb>
# <l>Und Duft entſchmeichelſt.</l>
# </lg>
# ######## error #########
# rhyme:
# ababccdedeff
# lines:
# ['jch bin verliebt mein hertze ist entzündet', 'durch deine pracht die mehr als menschlich ist']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="ababccdedeff" type="stanza">
# <l><hi rendition="#in">J</hi>ch bin verliebt/ mein Hertze iſt entzuͤndet/</l>
# <lb></lb>
# <l>Durch deine Pracht/ die mehr als menſchlich iſt:</l>
# <lb></lb>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababcdcdefefghghijij
# lines:
# ['der himmel heitert sich nach langen blitzen aus', 'und auf das donnern folgt ein helles sonnenscheinen', 'das glücke lacht zuletzt nach ausgestandnen strau', 'und ein erfreut gesicht beschleut das lange weinen', 'nach denen fasten bricht die osterwoche an', 'darinn ein jubelfest die treuen seelen halten', 'die ihren lauff gehabt auf einer dornen bahn', 'und mehr denn offt gemeynt sie müsten nun erkalten', 'der sommer süsser lust bricht nach dem winter ein', 'und das erstorbne feld bekommt ein neues leben']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="ababcdcdefefghghijij" type="stanza">
# <l><hi rendition="#in">D</hi>er Himmel heitert ſich nach langen Blitzen aus/</l>
# <lb></lb>
# <l>Und auf das Donnern folgt ein helles Sonnenſcheinen/</l>
# <lb></lb>
# <l>Das Gluͤcke lacht zuletzt nach ausgeſtandnen Strauß/</l>
# <lb></lb>
# <l>Und ein erfreut Geſicht beſchleußt das lange Weinen.</l>
# <lb></lb>
# <l>Nach denen Faſten bricht die Oſter-Woche an/</l>
# <lb></lb>
# <l>Darinn ein Jubel-Feſt die treuen Seelen halten/</l>
# <lb></lb>
# <fw place="bottom" type="catch">Die</fw>
# <lb></lb>
# <pb facs="#f0417" n="399"></pb>
# <fw place="top" type="header"><hi rendition="#b">Vermiſchte Gedichte.</hi></fw>
# <lb></lb>
# <l>Die ihren Lauff gehabt auf einer Dornen Bahn/</l>
# <lb></lb>
# <l>Und mehr denn offt gemeynt ſie muͤſten nun erkalten.</l>
# <lb></lb>
# <l>Der Sommer ſuͤſſer Luſt bricht nach dem Winter ein/</l>
# <lb></lb>
# <l>Und das erſtorbne Feld bekommt ein neues Leben/</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbcddcbbeffebbghhgbb
# lines:
# []
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="aabbcddcbbeffebbghhgbb" type="stanza">
# <l></l>
# <lb></lb>
# </lg>
#
#
# ######## error #########
# rhyme:
# abccb
# lines:
# []
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="abccb" type="stanza">
# <l></l>
# <lb></lb>
# </lg>
#
#
# ######## error #########
# rhyme:
# ababcdcdefe
# lines:
# ['mein mädgen das soll seyn', 'ein kind von bösen sinnen', 'des lippen sich erfreun', 'wenn sie frech schwatzen künnen', 'das frech und schöne ist', 'das schläge nimmt und giebet', 'das nach den schlägen küt', 'und desto hefftger liebet', 'wenn es nicht so gesinnt', 'kensch sitsahm ist hingegen', 'so schlag ichs in den wind', 'und wils nicht bey mir hegen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="ababcdcdefe" type="stanza">
# <l><hi rendition="#in">M</hi>ein Maͤdgen das ſoll ſeyn</l>
# <lb></lb>
# <l>Ein Kind von boͤſen Sinnen/</l>
# <lb></lb>
# <l>Des Lippen ſich erfreun</l>
# <lb></lb>
# <l>Wenn ſie frech ſchwatzen kuͤnnen.</l>
# <lb></lb>
# <l>Das frech und ſchoͤne iſt</l>
# <lb></lb>
# <l>Das Schlaͤge nimmt und giebet/</l>
# <lb></lb>
# <l>Das nach den Schlaͤgen kuͤßt/</l>
# <lb></lb>
# <l>Und deſto hefftger liebet.</l>
# <lb></lb>
# <l>Wenn es nicht ſo geſinnt/</l>
# <lb></lb>
# <l>Kenſch/ ſitſahm iſt hingegen/</l>
# <lb></lb>
# <l>So ſchlag’ ichs in den Wind/</l>
# <lb></lb>
# <l>Und wils nicht bey mir hegen.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbccddeeffgghhiijjkkll
# lines:
# ['mich hub des glückesgunst zu den gestirnten höhen', 'als ich die lesbia sah in mein zimmer gehen']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="aabbccddeeffgghhiijjkkll" type="stanza">
# <l><hi rendition="#in">M</hi>ich hub des Gluͤckes-Gunſt zu den geſtirnten Hoͤhen/</l>
# <lb></lb>
# <l>Als ich die <hi rendition="#aq">Lesbia</hi> ſah in mein Zimmer gehen/</l>
# <lb></lb>
# </lg>
#
#
# ######## error #########
# rhyme:
# a
# lines:
# ['so hat mein damon doch hyellens              sinn besiegt', 'und in der zarten schoo den liebesschatz gepräget']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gressel_JohannGeorg_1716_gold_p56_s141_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="38" rhyme="a" type="stanza">
# <hi rendition="#c"><hi rendition="#aq">Hyelle.</hi></hi>
# <lb></lb>
# <l>So hat mein <hi rendition="#aq">Damon</hi> doch <hi rendition="#aq">Hyellens</hi>
#               Sinn beſiegt/</l>
# <lb></lb>
# <l>Und in der zarten Schooß den Liebes-Schatz gepraͤget.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# aabbccddee
# lines:
# ['her jesis der friedli mi friedli isch do', 'gottwilche gottwilche wohl chenni di no', 'wohl het mi bigleitet di liebligi gstalt', 'uf duftige matten im schattige wald', 'wohl het di bigleitet mi bchümmeret herz', 'dur schwerdter und chugle mit hofnig', 'und schmerz', 'und briegget und bettet gott het mer will', 'fahrt', 'und het mer mi friedli und het mer en gspart', 'wie chlopfts mer im buese wie bini so froh', 'o muetter chumm weidli mi fridli isch do']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg rhyme="aabbccddee" type="stanza">
# <l>Her Jeſis, der Friedli, mi Friedli iſch do!</l>
# <lb></lb>
# <l>Gottwilche, Gottwilche, wohl chenni di no!</l>
# <lb></lb>
# <l>Wohl het mi bigleitet di liebligi Gſtalt,</l>
# <lb></lb>
# <l>uf duftige Matten im ſchattige Wald.</l>
# <lb></lb>
# <l>Wohl het di bigleitet mi b’chuͤmmeret Herz</l>
# <lb></lb>
# <l>dur Schwerdter und Chugle mit Hofnig</l>
# <lb></lb>
# <l>und Schmerz,</l>
# <lb></lb>
# <l>und briegget und bettet. Gott het mer will-</l>
# <lb></lb>
# <l>fahrt,</l>
# <lb></lb>
# <l>und het mer mi Friedli und het mer en gſpart.</l>
# <lb></lb>
# <l>Wie chlopfts mer im Bueſe, wie bini ſo froh!</l>
# <lb></lb>
# <l>O Muetter, chumm weidli, mi Fridli iſch do!</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ab
# lines:
# ['o aetti sag mer nüt me zwor wie gohts', 'de lüte denn wenn alles brennt und', 'brennt']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="1" rhyme="ab" type="stanza">
# <l>O Aetti, ſag mer nuͤt me! Zwor wie gohts</l>
# <lb></lb>
# <l>de Luͤte denn, wenn alles brennt und</l>
# <lb></lb>
# <l>brennt?</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ab
# lines:
# ['widrig ist mir fürwahr der wind den die orgel vergeudet', 'wenn aus der pfeife gejagt er nicht getraide noch', 'stäubt']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="2" rhyme="ab" type="stanza">
# <hi rendition="#g">Zweiter</hi>.
#             <lb></lb>
# <l>Widrig iſt mir fuͤrwahr der Wind, den die Orgel vergeudet,</l>
# <lb></lb>
# <l rendition="#et">Wenn, aus der Pfeife gejagt, er nicht Getraide noch</l>
# <lb></lb>
# <l>ſtaͤubt.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ab
# lines:
# ['widrig ist mir fürwahr jedwedes bildni von marmor', 'spendet nicht wasser sein mund trägt es nicht stützend', 'ein haus']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="4" rhyme="ab" type="stanza">
# <hi rendition="#g">Vierter</hi>.
#             <lb></lb>
# <l>Widrig iſt mir fuͤrwahr jedwedes Bildniß von Marmor,</l>
# <lb></lb>
# <l rendition="#et">Spendet nicht Waſſer ſein Mund, traͤgt es nicht ſtuͤtzend</l>
# <lb></lb>
# <l>ein Haus.</l>
# </lg>
#
#
# ######## error #########
# rhyme:
# ab
# lines:
# ['immer am widrigsten bleibt der schein des monds und', 'der sterne', 'nicht ein körnlein bei gott weckt ihr unpraktischer', 'stral']
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
# item:
# <lg n="5" rhyme="ab" type="stanza">
# <hi rendition="#g">Fuͤnfter</hi>.
#             <lb></lb>
# <l>Immer am widrigſten bleibt der Schein des Monds und</l>
# <lb></lb>
# <l>der Sterne,</l>
# <lb></lb>
# <l rendition="#et">Nicht ein Koͤrnlein, bei Gott! weckt ihr unpraktiſcher</l>
# <lb></lb>
# <l>Stral.</l>
# </lg>

# %%
no_rhyme_cnt
# Out:
# 168

# %% [markdown]
# # Just for illustration purposes
#
# The cell belows shows the inconsistent use for "<l><\l>" in the corpus.
#
# Sometimes "<\l>" comes inside a vers and sometimes indeed it marks the complete verse even if it spreads on two lines

# %%
for file in filenames:
    with open(file, "r",encoding="utf-8") as file:
        # Read each line in the file, readlines() returns a list of lines
        content = file.readlines()
        # Combine the lines in the list into a string
        content = "".join(content)
        bs_content = bs(content, "lxml")

    result = bs_content.find_all("lg")
    for item in result:
        bs_item = bs(str(item),'lxml')
        
        subitems = bs_item.find_all('lg')
        if len(subitems) <= 1:
            try:
                rhyme = re.search(r'rhyme=\"(.*?)\"', str(item)).group(1)
            except: 
                rhyme = 'z'
            lines = bs_item.find_all('l')
            
            for i in range(len(lines)):
                if re.search(r'<l><hi rendition="#et">',str(lines[i])):
                    print('#et at beginning of verse')
                    print('verse:')
                    print(str(lines[i]))
                    print('file:')
                    print(str(file))
                    
            for i in range(len(lines)):
                if (not re.search(r'<l><hi rendition="#et">',str(lines[i]))) and re.search(r'rendition="#et">',str(lines[i])):
                    print('\n')
                    print('#et inside verse')
                    print('verse:')
                    print(str(lines[i]))
                    print('file:')
                    print(str(file))
# Out:
# #et inside verse
# verse:
# <l>Daſs dich, mit goldenen Städten und<lb></lb>
# <hi rendition="#et">Schlachten,</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Ramler_KarlWilhelm_1767_gold_p9_s79_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l>
l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Von Lieb' und Hoffnung ſtill bewegt.</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Frag' nicht, wie dieſe Kraft man heißt;</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>
#
#
# #et inside verse
# verse:
# <l rendition="#et">Und ſprichſt: das that des Wildbads Geiſt!</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Kerner_Justinus_1826_gold_p15_s70_TEI-P5.xml' mode='r' encoding='utf-8'>

# %% [markdown]
# # Rendition test
#
# Find and display uses of different renditions

# %%
rendition ='rendition="#c'

for file in filenames:
    with open(file, "r",encoding="utf-8") as file:
        # Read each line in the file, readlines() returns a list of lines
        content = file.readlines()
        # Combine the lines in the list into a string
        content = "".join(content)
        bs_content = bs(content, "lxml")

    result = bs_content.find_all("lg")
    for item in result:
        bs_item = bs(str(item),'lxml')
        
        subitems = bs_item.find_all('lg')
        if len(subitems) <= 1:
            try:
                rhyme = re.search(r'rhyme=\"(.*?)\"', str(item)).group(1)
            except: 
                rhyme = 'z'
            lines = bs_item.find_all('l')
            
            for i in range(len(lines)):
                if re.search(rendition,str(lines[i])):
                    print('\n')
                    print('verse:')
                    print(str(lines[i]))
                    print('file:')
                    print(str(file))
                    line = re.sub('<[^>]+>', '', str(lines[i]))
                    print(line)
                    if line[:-1].isdecimal():
                        print('numeric')
# Out:
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">12.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 12.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Neumark_Georg_1666_gold_p63_s89_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">den:</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Abschatz_HansAssmannvon_1704_gold_p50_s95_TEI-P5.xml' mode='r' encoding='utf-8'>
# den:
#
#
# verse:
# <l>Mich kan kein fremder Zeug bey eignem Mangel ſchmuͤ-<lb></lb>
# <hi rendition="#c">cken/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Abschatz_HansAssmannvon_1704_gold_p50_s95_TEI-P5.xml' mode='r' encoding='utf-8'>
# Mich kan kein fremder Zeug bey eignem Mangel ſchmuͤ-
# cken/
#
#
# verse:
# <l><hi rendition="#c">ren an/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Abschatz_HansAssmannvon_1704_gold_p50_s95_TEI-P5.xml' mode='r' encoding='utf-8'>
# ren an/
#
#
# verse:
# <l><hi rendition="#c">winnen.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Abschatz_HansAssmannvon_1704_gold_p50_s95_TEI-P5.xml' mode='r' encoding='utf-8'>
# winnen.
#
#
# verse:
# <l>Wer kan mit Macht entgehn dem groſſen Allmachts-Grim-<lb></lb>
# <hi rendition="#c">me?</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Abschatz_HansAssmannvon_1704_gold_p50_s95_TEI-P5.xml' mode='r' encoding='utf-8'>
# Wer kan mit Macht entgehn dem groſſen Allmachts-Grim-
# me?
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">12.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 12.
# numeric
#
#
# verse:
# <l><hi rendition="#c">13.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 13.
# numeric
#
#
# verse:
# <l><hi rendition="#c">14.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 14.
# numeric
#
#
# verse:
# <l><hi rendition="#c">15.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 15.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi>
# <hi rendition="#et">(ſey/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# (ſey/
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi>
# <hi rendition="#et">(ben/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# (ben/
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi> (faͤhret/</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4. (faͤhret/
#
#
# verse:
# <l><hi rendition="#c">5.</hi> (len/</l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5. (len/
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">12.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 12.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi>
# <hi rendition="#et">(tzen/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# (tzen/
#
#
# verse:
# <l><hi rendition="#c">10.</hi>
# <hi rendition="#et">(men/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# (men/
#
#
# verse:
# <l><hi rendition="#c">11.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 11.
# numeric
#
#
# verse:
# <l><hi rendition="#c">12.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 12.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi>
# <hi rendition="#et">(Ruh/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# (Ruh/
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# ...
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi>
# <hi rendition="#et">(Erde/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# (Erde/
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi>
# <hi rendition="#et">(cken/</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# (cken/
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">1.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 1.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">2.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 2.
# numeric
#
#
# verse:
# <l><hi rendition="#c">3.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 3.
# numeric
#
#
# verse:
# <l><hi rendition="#c">4.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 4.
# numeric
#
#
# verse:
# <l><hi rendition="#c">5.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 5.
# numeric
#
#
# verse:
# <l><hi rendition="#c">6.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 6.
# numeric
#
#
# verse:
# <l><hi rendition="#c">7.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 7.
# numeric
#
#
# verse:
# <l><hi rendition="#c">8.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 8.
# numeric
#
#
# verse:
# <l><hi rendition="#c">9.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 9.
# numeric
#
#
# verse:
# <l><hi rendition="#c">10.</hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# 10.
# numeric
#
#
# verse:
# <l><hi rendition="#c"><hi rendition="#fr">Ach! vnd weh!</hi></hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gryphius_Andreas_1650_gold_p49_s189_TEI-P5.xml' mode='r' encoding='utf-8'>
# Ach! vnd weh!
#
#
# verse:
# <l><hi rendition="#c"><hi rendition="#fr">Tieff’ vnd Hoͤh’!</hi></hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gryphius_Andreas_1650_gold_p49_s189_TEI-P5.xml' mode='r' encoding='utf-8'>
# Tieff’ vnd Hoͤh’!
#
#
# verse:
# <l><hi rendition="#c"><hi rendition="#fr">Je vnd Eh!</hi></hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Gryphius_Andreas_1650_gold_p49_s189_TEI-P5.xml' mode='r' encoding='utf-8'>
# Je vnd Eh!
#
#
# verse:
# <l><hi rendition="#c"><hi rendition="#aq">Roſ.</hi></hi></l>
# file:
# <_io.TextIOWrapper name='rhyme_corpus/Weise_Christian_1701_gold_p49_s308_TEI-P5.xml' mode='r' encoding='utf-8'>
# Roſ.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-95e7c898bbf3> in <module>
#      11     result = bs_content.find_all("lg")
#      12     for item in result:
# ---> 13         bs_item = bs(str(item),'lxml')
#      14
#      15         subitems = bs_item.find_all('lg')
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     346             self.reset()
#     347             try:
# --> 348                 self._feed()
#     349                 success = True
#     350                 break
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/__init__.py in _feed(self)
#     432         self.builder.reset()
#     433
# --> 434         self.builder.feed(self.markup)
#     435         # Close out any unfinished strings and close all the open tags.
#     436         self.endData()
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/builder/_lxml.py in feed(self, markup)
#     322         try:
#     323             self.parser = self.parser_for(encoding)
# --> 324             self.parser.feed(markup)
#     325             self.parser.close()
#     326         except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed()
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxTargetStartNoNs()
#
# src/lxml/saxparser.pxi in lxml.etree._callTargetSaxStart()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/builder/_lxml.py in start(self, name, attrs, nsmap)
#     255         namespace, name = self._getNsTag(name)
#     256         nsprefix = self._prefix_for_namespace(namespace)
# --> 257         self.soup.handle_starttag(name, namespace, nsprefix, attrs)
#     258
#     259     def _prefix_for_namespace(self, namespace):
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos)
#     694         """
#     695         # print("Start tag %s: %s" % (name, attrs))
# --> 696         self.endData()
#     697
#     698         if (self.parse_only and len(self.tagStack) <= 1
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/__init__.py in endData(self, containerClass)
#     543         occurs.
#     544         """
# --> 545         containerClass = self.string_container(containerClass)
#     546
#     547         if self.current_data:
#
# ~/.conda/envs/tf36/lib/python3.6/site-packages/bs4/__init__.py in string_container(self, base_class)
#     486         # On top of that, we may be inside a tag that needs a special
#     487         # container class.
# --> 488         if self.string_container_stack:
#     489             container = self.builder.string_containers.get(
#     490                 self.string_container_stack[-1].name, container
#
# KeyboardInterrupt:

# %%
rhyme_df = pd.DataFrame(list(zip(line_lst, rhyme_lst,problem_lst,f_lst)),
               columns =['text', 'rhyme','problem','file'])

# %%
rhyme_df.to_csv('rhyme_df.csv')

# %%
rhyme_df
# Out:
#                                                    text rhyme  problem  \
# 0     [o du dem glühend eisen donnerndfeuer, aus off...  abab        0
# 1     [wer zur verheerung blühender geschlechter, di...  abab        0
# 2     [ganz nahe war ich schon dem styxganz nahe, de...  abab        0
# 3     [verdammt zum spott bey bodenlosenfässern, und...  abab        0
# 4     [voll tapfrer brennen sah ich ihrelieder, ihr ...  abab        0
# ...                                                 ...   ...      ...
# 8359  [quält schmerz und krankheit deine glieder, ma...  abab        0
# 8360  [hier legt natur mit linden armen, dich an die...  abab        0
# 8361  [der wasser gute geister singen, hier aus krys...  abab        0
# 8362  [ja kranker wie ein kind ans herze, der mutter...  abab        0
# 8363  [wie lenzeshauch wirds dich durchbeben, frag n...  abab        0
#
#                                                    file
# 0     <_io.TextIOWrapper name='rhyme_corpus/Ramler_K...
# 1     <_io.TextIOWrapper name='rhyme_corpus/Ramler_K...
# 2     <_io.TextIOWrapper name='rhyme_corpus/Ramler_K...
# 3     <_io.TextIOWrapper name='rhyme_corpus/Ramler_K...
# 4     <_io.TextIOWrapper name='rhyme_corpus/Ramler_K...
# ...                                                 ...
# 8359  <_io.TextIOWrapper name='rhyme_corpus/Kerner_J...
# 8360  <_io.TextIOWrapper name='rhyme_corpus/Kerner_J...
# 8361  <_io.TextIOWrapper name='rhyme_corpus/Kerner_J...
# 8362  <_io.TextIOWrapper name='rhyme_corpus/Kerner_J...
# 8363  <_io.TextIOWrapper name='rhyme_corpus/Kerner_J...
#
# [8364 rows x 4 columns]

# %%
import preprocess_rhymes

# %%
preprocess_rhymes()

# %%
sent = ['der baum','ich will','die bill','ein traum']
rhyme_pairs = []
no_rhyme_pairs = []

rhyme_df_clean = rhyme_df.drop(rhyme_df[rhyme_df['problem']>0].index)

for index, row in rhyme_df_clean.iterrows():
    
    scheme = row['rhyme']
    sent = row['text']
    file = row['file']
    new_pairs = []
    letters = set(scheme)
    for letter in letters:
        indices = [idx for idx, char in enumerate(scheme) if char == letter]
        
        if len(indices) >= 2: 
            new_pair = [sent[i].split()[-1] for i in indices]
            new_pairs.append(new_pair)
                
            if len(indices) > 2:
                rhyme_pairs += [list(item) for item in list(itertools.combinations(new_pair,2))]
            elif len(indices) == 2:
                rhyme_pairs.append(new_pair)

        else:
            #print(sent)
            #print(scheme)
            #print(indices)
            pass
        
    for idx in range(len(new_pairs)-1):                                          # ugly, but does the job fast
        try:
            no_rhyme_pairs.append([new_pairs[idx][0],new_pairs[idx+1][0]])
            no_rhyme_pairs.append([new_pairs[idx][1],new_pairs[idx+1][1]])
        except:
            pass
# Out:
# ['oanfang sonder ende', 'du grosses a und o', 'wir küssen deine hände', 'und sind von hertzen froh', 'weil du uns noch ein jahr', 'mit segen läst beschlüssen', 'da wir bekennen müssen', 'dein thun sey wunderbar']
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['der letzte wochentag                            ist hin', 'davor ich dir verbunden bin', 'du bist mein gott das a und o', 'und deine weiheit schafft es so']
# <_io.TextIOWrapper name='rhyme_corpus/Schmolck_Benjamin_1712_gold_p44_s420_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['mein freund ein schüler von apollen', 'ein meister in der homelie herr professor e  b                                 d', 'glaubt da die tauben küssen wollen', 'aus zärtlichkeit und harmonie']
# <_io.TextIOWrapper name='rhyme_corpus/Karsch_AnnaLuise_1792_gold_p7_s50_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['so lange eine menschheit ist', 'so lange jesus bleibt der christ', 'so bleibet di das a und o', 'vom gantzen evangelio', 'und da dasselbige die weiheit ist', 'das wit ihr alle die ihr wahrheit wit']
# <_io.TextIOWrapper name='rhyme_corpus/Zinzendorf_NicolausLudwigvon_1735_gold_p23_s289_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['doch hört nur mein monsieur', 'verstand die fintenvolle', 'vorherstudirte rolle', 'wie ich mein a b c', 'war er aktör ich wette', 'da man geklatschet hätte']
# <_io.TextIOWrapper name='rhyme_corpus/BБrger_GottfriedAugust_1778_gold_p34_s360_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['drum rath ich immer lieber christ', 'las dich mit keinem ein', 'wann der kontrakt geschlossen ist', 'bricht man dir hals und bein', 'troz allen klauseln glaube du', 'macht jeder dir ein x für u ']
# <_io.TextIOWrapper name='rhyme_corpus/BБrger_GottfriedAugust_1778_gold_p34_s360_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['im letste wirthshus hangt e sack', 'und wenn de furt gohsch henk en a', 'du alte lump wie stoht der nit', 'der bettelsack so zierlig a']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['druf redt der chnab mi büebli a', 'was iisch i halts mit ', 'he nüt seit s büebli luegt en a', 'und lüpft si chäppli nit', 'druf seit der chnab he iisch nüt', 'du grobe burst se battet s nüt']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['wer spöchtet mer mi hexli us', 'wer zeigtmer siner mutter hus', 'j lauf no was i laufe cha', 'wer wei se triffis doch no a']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['weisch jobbeli was der morgestern', 'am himmel sucht me seits nit gern', 'er wandlet imme sternli no', 'er cha schier gar nit vonnem lo', 'doch meint si mutter s müe nit sy', 'und thut en wie ne hüenli i']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['dört chunnt sie scho i has io gseit', 'in ihrer stille herlichkeit', 'sie zündet ihri strahlen a', 'der chilchthurn wärmt si au scho dra', 'und wo sie fallen in berg und thal', 'se rüehrt si s leben überal']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['was wandlet dört im morgestral', 'mit tuch und chorb durs mattethal', 's sin dmeidli iung und flink und froh', 'sie bringe weger dsnppesuppe scho', 'und s anne meili vornen a', 'es lacht mi scho vo witem a']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['und wemme gchämpft mu ha', 'gohts meini ehnder no a', 'im freie dusse wo d sunn o lacht', 'do innen ischs zum bitrüebe', 'chromet geli rüebe', 'sie hen schier alliwil nacht']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# 

# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>
# ['und glitte was me lide cha', 'drum schenket i und stoet a', 'uf völker fried und einigkeit', 'vo nun a bis in ewigkeit']
# <_io.TextIOWrapper name='rhyme_corpus/Hebel_JohannPeter_1803_gold_p12_s113_TEI-P5.xml' mode='r' encoding='utf-8'>

# %%
rhyme_stat = [1]*len(rhyme_pairs) + [0]*len(no_rhyme_pairs)
pairs = rhyme_pairs + no_rhyme_pairs

for pair in pairs:
    
    if len(pair) < 1:
        print(pair)
word_1 = [pair[0] for pair in pairs]
word_2 = [pair[1] for pair in pairs]

rhyme_word_df = pd.DataFrame(list(zip(word_1, word_2,rhyme_stat)),
               columns =['word1', 'word2','rhyme'])

# %%
rhyme_word_df
# Out:
#                word1                   word2  rhyme
# 0      donnerndfeuer  zerschmetternungeheuer      1
# 1             flammt                  stammt      1
# 2       geschlechter            seinetöchter      1
# 3           gebracht              umgebracht      1
# 4               nahe             rasselnsahe      1
# ...              ...                     ...    ...
# 43440        bringen                vertraut      0
# 43441          herze                    legt      0
# 43442       schmerze                  bewegt      0
# 43443     durchbeben                    heit      0
# 43444          leben                   geist      0
#
# [43445 rows x 3 columns]

# %%
stat_df = rhyme_word_df.copy()

stat_df['len word1'] = stat_df['word1'].apply(lambda x: len(x))
stat_df['len word2'] = stat_df['word2'].apply(lambda x: len(x))
pd.set_option('display.max_rows', 200)
stat_df.sort_values(by=['len word2']).head(100)
# Out:
#                      word1 word2  rhyme  len word1  len word2
# 43041                 keim     a      0          4          1
# 20259                    a     a      1          1          1
# 20081                    a     a      1          1          1
# 28217                 jahr     o      0          4          1
# 42818                  hus     a      0          3          1
# 20281                   la     a      1          2          1
# 20156                   ha     a      1          2          1
# 42842                 gern     i      0          4          1
# 41848                  ist     u      0          3          1
# 19279                   du     u      1          2          1
# 42995                 echt     a      0          4          1
# 20309                   ma     a      1          2          1
# 20145                    a     a      1          1          1
# 20258                  cha     a      1          3          1
# 42965                   io     a      0          2          1
# 42865           morgestral     a      0         10          1
# 20353                  cha     a      1          3          1
# 42982                 gott     a      0          4          1
# 20325                   ma     a      1          2          1
# 20108                  cha     a      1          3          1
# 20327              biderma     a      1          7          1
# 36297                  ist     o      0          3          1
# 42936                stoht     i      0          5          1
# 20127                   sy     i      1          2          1
# 42859                 thal     a      0          4          1
# 33207              apollen     d      0          7          1
# 19123             monsieur     c      1          8          1
# 42866            mattethal     a      0          9          1
# 20257                  cha     a      1          3          1
# 20295                   ma     a      1          2          1
# 20069                    a     a      1          1          1
# 20198                   ma     a      1          2          1
# 20232                   ma     a      1          2          1
# 20197            morgeschi     i      1          9          1
# 28697                  hin     o      0          3          1
# 20204                   ma     a      1          2          1
# 24718              gesogen    an      0          7          2
# 1012              gleichlo    ro      1          8          2
# 42675       jungferschafft    sü      0         14          2
# 36330                  her    an      0          3          2
# 27336                würde    ba      0          5          2
# 1922                  nahn    an      1          4          2
# 11102                  ruh    zu      1          3          2
# 892                    nah    da      1          3          2
# 11108                 dann    an      1          4          2
# 36331             bestellt    du      0          8          2
# 36332                 welt    du      0          4          2
# 20998  feuerspeyndenrachen    da      0         19          2
# 1986                    an    an      1          2          2
# 11115                 kann    an      1          4          2
# 29389             springet    ju      0          8          2
# 6312                  grab    ab      1          4          2
# 9288                  etat    da      1          4          2
# 29386                 alda    zu      0          4          2
# 11122                daher    er      1          5          2
# 32611                  mir    an      0          3          2
# 11124                   zu    du      1          2          2
# 17427                 flei    ei      1          4          2
# 36356                windt    da      0          5          2
# 3189                    an    an      1          2          2
# 4442                hurrah    da      1          6          2
# 32761               gehege    an      0          6          2
# 11128                 mann    an      1          4          2
# 34263                drauf    ab      0          5          2
# 22877                tagen    an      0          5          2
# 20941      frankensprechet    an      0         15          2
# 22878        ausgeschlagen    an      0         13          2
# 19114                  ruh    zu      1          3          2
# 18976                  her    er      1          3          2
# 14869           hallelujah    da      1         10          2
# 14868                  sah    da      1          3          2
# 14692                 gewi    di      1          4          2
# 32512                ehren    an      0          5          2
# 27422               fische    an      0          6          2
# 23088        hahnreyschaft    an      0         13          2
# 6859                   kan    an      1          3          2
# 28621              anficht    ge      0          7          2
# 4455                hurrah    da      1          6          2
# 28698                  bin    so      0          3          2
# 4454                hurrah    da      1          6          2
# 42981                 brod    ma      0          4          2
# 23081              gesteht    so      0          7          2
# 28625                steht    an      0          5          2
# 4451                hurrah    da      1          6          2
# 4450                hurrah    da      1          6          2
# 4447                hurrah    da      1          6          2
# 4446                hurrah    da      1          6          2
# 11087                  ruh    zu      1          3          2
# 42266              geküsst    an      0          7          2
# 4443                hurrah    da      1          6          2
# 26515                 ehre    an      0          4          2
# 4312                   ruh    zu      1          3          2
# 6282                    du    zu      1          2          2
# 4331                    zu    du      1          2          2
# 38027               garten    ku      0          6          2
# 38026             hortulan    zu      0          8          2
# 38025                   an    du      0          2          2
# 38023              beweget    an      0          7          2
# 22985                 wort    du      0          4          2
# 13721                 dann    an      1          4          2

# %%
shuffled_df = rhyme_word_df.sample(frac=1).reset_index(drop=True)

# %%
ratio = 0.8

df_train = shuffled_df[:int(len(shuffled_df)*ratio)]
df_val = shuffled_df[int(len(shuffled_df)*ratio):]

df_train.to_csv('data/train.csv',index=False)
df_val.to_csv('data/val.csv',index=False)

shuffled_df.to_csv('data/rhymes_clean.csv', index=False)

# %%
label_dict = {1:'y',0:'n'}

train_data_df = shuffled_df.copy()

train_data_df['rhyme'] = train_data_df['rhyme'].apply(lambda x: label_dict[x])

train_data_df.to_csv('data/rhymes_clean.tsv', index=False, sep='\t',header = None)


train_data_df
# Out:
#             word1         word2 rhyme
# 0         geblühm         dräut     n
# 1         gleicht        anbeut     n
# 2          saamen         namen     y
# 3          bliebe         liebe     y
# 4         wiedere       niedere     y
# ...           ...           ...   ...
# 42633  geschlacht       gemacht     y
# 42634      rächet     schwächet     y
# 42635      bereit      ewigkeit     y
# 42636       leise          brot     n
# 42637       empor  felsengrotte     n
#
# [42638 rows x 3 columns]

# %%
len('abec de')
# Out:
# 7
