# %% [markdown]
# # Manually evaluating the rhyme model

# %%
from siamese_rhyme import siamese_rhyme
import pandas as pd
import torch.nn.functional as F


model = siamese_rhyme(load=True)

# %%
def flip_words(df,columns = ['word1','word2']):
    for column in columns: 
        df[column] = df[column].apply(lambda x: x[::-1])
        
    return df

def get_word_vecs(df,columns = ['word1','word2']):    
    df['vec1'] = df[columns[0]].apply(lambda x: model.get_word_vec(x))
    df['vec2'] = df[columns[1]].apply(lambda x: model.get_word_vec(x))
    return df
    
def get_distances(df):
    df['dist'] = df.apply(lambda x: 1- F.cosine_similarity(x.vec1,x.vec2).cpu().detach().numpy()[0],axis=1)
    return df

def get_predictions(df,value):
    df['pred'] = df['dist'].apply(lambda x: int(x<value))
    return df

# %%
def flip_words(df,columns = ['word1','word2']):
    for column in columns: 
        df[column] = df[column].apply(lambda x: x[::-1])
        
    return df

# %%
df_train = pd.read_csv('data/train.csv')

df_train = flip_words(df_train)

df_train
# Out:
#                 word1          word2  rhyme
# 0           eigenthum            mir      0
# 1              schwül          üplfh      0
# 2               meise    heunenreise      1
# 3        gitterstäben  hinunterweenb      0
# 4      laternenschein           koth      0
# ...               ...            ...    ...
# 42739          sinnen       bgneenni      0
# 42740       finsterni    sonnenlicht      0
# 42741         schreit          speit      1
# 42742           zeigt         seelen      0
# 42743          grimme         hinnen      0
#
# [42744 rows x 3 columns]

# %%
df_train_pred = get_distances(get_word_vecs(df_train))

# %%
df_train_pred = get_predictions(df_train_pred, 0.45)

# %%
df_false = df_train_pred.loc[df_train_pred['rhyme'] != df_train_pred['pred']]

df_false
# Out:
#             word1        word2  rhyme  \
# 70           fült      vergilt      0
# 83           beut        braut      0
# 101         nennt       trennt      0
# 150          kinn          hin      0
# 166        scharf         warf      0
# ...           ...          ...    ...
# 42670  seltenheit  dankbarkeit      0
# 42685     unterla           ba      1
# 42691        paar          war      0
# 42702        kauf         lauf      0
# 42711      schuld         huld      0
#
#                                                     vec1  \
# 70     [[tensor(-0.0874, device='cuda:0', grad_fn=<Un...
# 83     [[tensor(0.6734, device='cuda:0', grad_fn=<Unb...
# 101    [[tensor(1.7195, device='cuda:0', grad_fn=<Unb...
# 150    [[tensor(-0.5106, device='cuda:0', grad_fn=<Un...
# 166    [[tensor(-0.5596, device='cuda:0', grad_fn=<Un...
# ...                                                  ...
# 42670  [[tensor(-0.0609, device='cuda:0', grad_fn=<Un...
# 42685  [[tensor(0.4569, device='cuda:0', grad_fn=<Unb...
# 42691  [[tensor(-0.3231, device='cuda:0', grad_fn=<Un...
# 42702  [[tensor(-1.5053, device='cuda:0', grad_fn=<Un...
# 42711  [[tensor(1.0879, device='cuda:0', grad_fn=<Unb...
#
#                                                     vec2      dist  pred
# 70     [[tensor(1.2055, device='cuda:0', grad_fn=<Unb...  0.225376     1
# 83     [[tensor(-0.4566, device='cuda:0', grad_fn=<Un...  0.293041     1
# 101    [[tensor(1.7264, device='cuda:0', grad_fn=<Unb...  0.026631     1
# 150    [[tensor(-0.3997, device='cuda:0', grad_fn=<Un...  0.219374     1
# 166    [[tensor(-0.0294, device='cuda:0', grad_fn=<Un...  0.069962     1
# ...                                                  ...       ...   ...
# 42670  [[tensor(0.4352, device='cuda:0', grad_fn=<Unb...  0.300585     1
# 42685  [[tensor(-1.0586, device='cuda:0', grad_fn=<Un...  0.568108     0
# 42691  [[tensor(0.8569, device='cuda:0', grad_fn=<Unb...  0.193058     1
# 42702  [[tensor(-1.6217, device='cuda:0', grad_fn=<Un...  0.067199     1
# 42711  [[tensor(1.2958, device='cuda:0', grad_fn=<Unb...  0.080107     1
#
# [1853 rows x 7 columns]

# %% [markdown]
# ## it was found that a decision boundary of around 0.45 works best on the train set

# %%
df_val = pd.read_csv('data/val.csv')

df_val = flip_words(df_val)

df_val
# Out:
#               word1     word2  rhyme
# 0              ring      ging      1
# 1               reg       weg      1
# 2              wein     freun      1
# 3             bahre     kleid      0
# 4              lauf      blut      0
# ...             ...       ...    ...
# 10682       brausen     nicht      0
# 10683        jahren  bewahren      1
# 10684         flehn     beten      0
# 10685        lieben      mehr      0
# 10686  sonnenschein      seyn      1
#
# [10687 rows x 3 columns]

# %%
df_val_pred = get_distances(get_word_vecs(df_val))
df_val_pred = get_predictions(df_val_pred, 0.45)


df_false = df_val_pred.loc[df_val_pred['rhyme'] != df_val_pred['pred']]

df_false
# Out:
#              word1         word2  rhyme  \
# 17           quell   trautgesell      0
# 18          triebe         elibe      0
# 19          zinnen  städterinnen      0
# 24     fischerkahn            an      1
# 39         erhielt         fühlt      0
# ...            ...           ...    ...
# 10541      schalle         halle      0
# 10560      gefällt         fällt      0
# 10567           ma             a      0
# 10595          nit        dermit      0
# 10621          kan            an      0
#
#                                                     vec1  \
# 17     [[tensor(-0.5122, device='cuda:0', grad_fn=<Un...
# 18     [[tensor(-1.9753, device='cuda:0', grad_fn=<Un...
# 19     [[tensor(0.4635, device='cuda:0', grad_fn=<Unb...
# 24     [[tensor(0.7715, device='cuda:0', grad_fn=<Unb...
# 39     [[tensor(0.1579, device='cuda:0', grad_fn=<Unb...
# ...                                                  ...
# 10541  [[tensor(-0.5467, device='cuda:0', grad_fn=<Un...
# 10560  [[tensor(0.5290, device='cuda:0', grad_fn=<Unb...
# 10567  [[tensor(-1.1135, device='cuda:0', grad_fn=<Un...
# 10595  [[tensor(1.2828, device='cuda:0', grad_fn=<Unb...
# 10621  [[tensor(1.1764, device='cuda:0', grad_fn=<Unb...
#
#                                                     vec2      dist  pred
# 17     [[tensor(-2.0960, device='cuda:0', grad_fn=<Un...  0.219652     1
# 18     [[tensor(-2.5342, device='cuda:0', grad_fn=<Un...  0.439913     1
# 19     [[tensor(0.6619, device='cuda:0', grad_fn=<Unb...  0.196575     1
# 24     [[tensor(0.0998, device='cuda:0', grad_fn=<Unb...  0.541865     0
# 39     [[tensor(1.2007, device='cuda:0', grad_fn=<Unb...  0.198892     1
# ...                                                  ...       ...   ...
# 10541  [[tensor(-0.1072, device='cuda:0', grad_fn=<Un...  0.063353     1
# 10560  [[tensor(0.9425, device='cuda:0', grad_fn=<Unb...  0.021355     1
# 10567  [[tensor(-0.0675, device='cuda:0', grad_fn=<Un...  0.239272     1
# 10595  [[tensor(1.5895, device='cuda:0', grad_fn=<Unb...  0.268855     1
# 10621  [[tensor(0.0998, device='cuda:0', grad_fn=<Unb...  0.173191     1
#
# [573 rows x 7 columns]

# %% [markdown]
# on the small sample it looks as if the validation set contains quite some false negatives, which is partially
# due to the synthetic data generation
